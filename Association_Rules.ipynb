# %%
#Import the libraries
import math
import pandas_datareader as web
import numpy as np
import pandas as pd

# %%
#Load the data
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-1ecccff5-93a3-42d7-b78c-b415b08e7a8e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1ecccff5-93a3-42d7-b78c-b415b08e7a8e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Lab2_store_data.csv to Lab2_store_data.csv

# %%
df = pd.read_csv("Lab2_store_data.csv", header = None)

# %%
df
# Out:
#                  0                  1   ...       18         19
# 0            shrimp            almonds  ...  spinach  olive oil
# 1           burgers          meatballs  ...      NaN        NaN
# 2           chutney                NaN  ...      NaN        NaN
# 3            turkey            avocado  ...      NaN        NaN
# 4     mineral water               milk  ...      NaN        NaN
# ...             ...                ...  ...      ...        ...
# 7496         butter         light mayo  ...      NaN        NaN
# 7497        burgers  frozen vegetables  ...      NaN        NaN
# 7498        chicken                NaN  ...      NaN        NaN
# 7499       escalope          green tea  ...      NaN        NaN
# 7500           eggs    frozen smoothie  ...      NaN        NaN
#
# [7501 rows x 20 columns]

# %%
df.shape
# Out:
# (7501, 20)

# %%
#Total number of Transactions
no_of_trans = df.shape[0]

# %%
#Converting the pandas dataframe into a list of lists
record = []
for i in range(0,7501):
  record.append([str(df.values[i,j]) for j in range(0, 20)])

# %%
record
# Out:
# [['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese',
#   'energy drink',
#   'tomato juice',
#   'low fat yogurt',
#   'green tea',
#   'honey',
#   'salad',
#   'mineral water',
#   'salmon',
#   'antioxydant juice',
#   'frozen smoothie',
#   'spinach',
#   'olive oil'],
#  ['burgers',
#   'meatballs',
#   'eggs',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['chutney',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['turkey',
#   'avocado',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['mineral water',
#   'milk',
#   'energy bar',
#   'whole wheat rice',
#   'green tea',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['low fat yogurt',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['whole wheat pasta',
#   'french fries',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['soup',
#   'light cream',
#   'shallot',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['frozen vegetables',
#   'spaghetti',
#   'green tea',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['french fries',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['eggs',
#   'pet food',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['cookies',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['turkey',
#   'burgers',
#   'mineral water',
#   'eggs',
#   'cooking oil',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['spaghetti',
#   'champagne',
#   'cookies',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['mineral water',
#   'salmon',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['mineral water',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['shrimp',
#   'chocolate',
#   'chicken',
#   'honey',
#   'oil',
#   'cooking oil',
#   'low fat yogurt',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['turkey',
#   'eggs',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['turkey',
#   'fresh tuna',
#   'tomatoes',
#   'spaghetti',
#   'mineral water',
#   'black tea',
#   'salmon',
#   'eggs',
#   'chicken',
#   'extra dark chocolate',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['meatballs',
#   'milk',
#   'honey',
#   'french fries',
#   'protein bar',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['red wine',
#   'shrimp',
#   'pasta',
#   'pepper',
#   'eggs',
#   'chocolate',
#   'shampoo',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['rice',
#   'sparkling water',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['spaghetti',
#   'mineral water',
#   'ham',
#   'body spray',
#   'pancakes',
#   'green tea',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['burgers',
#   'grated cheese',
#   'shrimp',
#   'pasta',
#   'avocado',
#   'honey',
#   'white wine',
#   'toothpaste',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['eggs',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['parmesan cheese',
#   'spaghetti',
#   'soup',
#   'avocado',
#   'milk',
#   'fresh bread',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['ground beef',
#   'spaghetti',
#   'mineral water',
#   'milk',
#   'energy bar',
#   'black tea',
#   'salmon',
#   'frozen smoothie',
#   'escalope',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['sparkling water',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['mineral water',
#   'eggs',
#   'chicken',
#   'chocolate',
#   'french fries',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['frozen vegetables',
#   'spaghetti',
#   'yams',
#   'mineral water',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['herb & pepper',
#   'tomato sauce',
#   'light cream',
#   'magazines',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['mineral water',
#   'chocolate',
#   'avocado',
#   'eggs',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['turkey',
#   'french fries',
#   'strawberries',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['frozen vegetables',
#   'strong cheese',
#   'chocolate',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['cookies',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['pickles',
#   'spaghetti',
#   'salmon',
#   'escalope',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['energy bar',
#   'french fries',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['red wine',
#   'ground beef',
#   'mineral water',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['mineral water',
#   'cake',
#   'cottage cheese',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['pickles',
#   'champagne',
#   'green tea',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['spaghetti',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['fresh tuna',
#   'frozen vegetables',
#   'spaghetti',
#   'mineral water',
#   'honey',
#   'whole wheat rice',
#   'frozen smoothie',
#   'escalope',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['spaghetti',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['soup',
#   'meatballs',
#   'hot dogs',
#   'sparkling water',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['escalope',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['soup',
#   'avocado',
#   'french fries',
#   'hot dogs',
#   'brownies',
#   'body spray',
#   'pancakes',
#   'green tea',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['mineral water',
#   'chicken',
#   'cereals',
#   'clothes accessories',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['mineral water',
#   'bug spray',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['avocado',
#   'muffins',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['burgers',
#   'black tea',
#   'green tea',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['spaghetti',
#   'chocolate',
#   'brownies',
#   'white wine',
#   'green tea',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['fresh tuna',
#   'mineral water',
#   'eggs',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['spaghetti',
#   'muffins',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['spaghetti',
#   'chocolate',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['french fries',
#   'escalope',
#   'champagne',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['tomato sauce',
#   'light mayo',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['turkey',
#   'fresh tuna',
#   'frozen vegetables',
#   'tomatoes',
#   'ground beef',
#   'spaghetti',
#   'mineral water',
#   'chocolate',
#   'soup',
#   'milk',
#   'olive oil',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['eggs',
#   'cookies',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['soup',
#   'chicken',
#   'gums',
#   'soda',
#   'body spray',
#   'energy drink',
#   'green tea',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['turkey',
#   'frozen vegetables',
#   'mineral water',
#   'cider',
#   'cooking oil',
#   'green tea',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['spaghetti',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['clothes accessories',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['energy drink',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['soup',
#   'bug spray',
#   'shallot',
#   'protein bar',
#   'green tea',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['turkey',
#   'eggs',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['french fries',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['chocolate',
#   'milk',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['herb & pepper',
#   'whole wheat pasta',
#   'ground beef',
#   'mineral water',
#   'avocado',
#   'cider',
#   'whole wheat rice',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['cookies',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['shrimp',
#   'pasta',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['grated cheese',
#   'herb & pepper',
#   'tomatoes',
#   'tomato sauce',
#   'corn',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['burgers',
#   'escalope',
#   'shallot',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['cookies',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['yogurt cake',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['soup',
#   'eggs',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['cookies',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['mineral water',
#   'chocolate',
#   'low fat yogurt',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['eggs',
#   'strawberries',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['grated cheese',
#   'ground beef',
#   'spaghetti',
#   'mineral water',
#   'white wine',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['mint',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['eggs',
#   'cake',
#   'french fries',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['burgers',
#   'spaghetti',
#   'milk',
#   'french fries',
#   'green tea',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['mineral water',
#   'energy bar',
#   'butter',
#   'french fries',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['burgers',
#   'grated cheese',
#   'herb & pepper',
#   'mineral water',
#   'eggs',
#   'cooking oil',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['energy bar',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['energy bar',
#   'energy drink',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['chocolate',
#   'frozen smoothie',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['low fat yogurt',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['asparagus',
#   'salad',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['burgers',
#   'french fries',
#   'low fat yogurt',
#   'green tea',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['low fat yogurt',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['burgers',
#   'herb & pepper',
#   'shrimp',
#   'pasta',
#   'spaghetti',
#   'mineral water',
#   'meatballs',
#   'olive oil',
#   'energy bar',
#   'french wine',
#   'eggs',
#   'salt',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['champagne',
#   'low fat yogurt',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['champagne',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['burgers',
#   'almonds',
#   'eggs',
#   'french fries',
#   'cookies',
#   'green tea',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['ham',
#   'soup',
#   'escalope',
#   'body spray',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['turkey',
#   'ham',
#   'frozen vegetables',
#   'pepper',
#   'oil',
#   'extra dark chocolate',
#   'tea',
#   'magazines',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['muffins',
#   'eggs',
#   'cookies',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['cookies',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['frozen vegetables',
#   'whole wheat pasta',
#   'ground beef',
#   'spaghetti',
#   'chocolate',
#   'green tea',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['mineral water',
#   'barbecue sauce',
#   'chocolate',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['burgers',
#   'herb & pepper',
#   'energy bar',
#   'almonds',
#   'eggs',
#   'corn',
#   'mayonnaise',
#   'zucchini',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['turkey',
#   'burgers',
#   'ground beef',
#   'chocolate',
#   'soup',
#   'almonds',
#   'eggs',
#   'hot dogs',
#   'cottage cheese',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['ham',
#   'spaghetti',
#   'chocolate',
#   'eggs',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['ground beef',
#   'energy bar',
#   'pet food',
#   'carrots',
#   'protein bar',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['ground beef',
#   'tomato sauce',
#   'spaghetti',
#   'mineral water',
#   'almonds',
#   'eggs',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['mineral water',
#   'olive oil',
#   'gums',
#   'cooking oil',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['shrimp',
#   'pasta',
#   'mineral water',
#   'soup',
#   'avocado',
#   'milk',
#   'olive oil',
#   'green grapes',
#   'eggs',
#   'bug spray',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['shrimp',
#   'pasta',
#   'soup',
#   'cake',
#   'cooking oil',
#   'chicken',
#   'light mayo',
#   'low fat yogurt',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['spaghetti',
#   'mineral water',
#   'chocolate',
#   'french fries',
#   'champagne',
#   'escalope',
#   'mushroom cream sauce',
#   'fresh bread',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['shrimp',
#   'pasta',
#   'mineral water',
#   'eggs',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['burgers',
#   'oil',
#   'tomato juice',
#   'fresh bread',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['french wine',
#   'eggs',
#   'chocolate',
#   'low fat yogurt',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['chicken',
#   'eggs',
#   'french fries',
#   'pancakes',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['turkey',
#   'herb & pepper',
#   'salmon',
#   'white wine',
#   'candy bars',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['grated cheese',
#   'spaghetti',
#   'olive oil',
#   'eggs',
#   'french fries',
#   'green tea',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['mineral water',
#   'energy bar',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['eggs',
#   'french fries',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['burgers',
#   'tomatoes',
#   'mineral water',
#   'soup',
#   'milk',
#   'almonds',
#   'eggs',
#   'chocolate',
#   'tomato juice',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['muffins',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['pasta',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['tomatoes',
#   'spaghetti',
#   'frozen smoothie',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['ground beef',
#   'spaghetti',
#   'milk',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['french fries',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['chocolate',
#   'milk',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['burgers',
#   'shrimp',
#   'pasta',
#   'frozen vegetables',
#   'spaghetti',
#   'mineral water',
#   'milk',
#   'eggs',
#   'chocolate',
#   'french fries',
#   'pancakes',
#   'low fat yogurt',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['ground beef',
#   'mineral water',
#   'antioxydant juice',
#   'protein bar',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['grated cheese',
#   'whole wheat pasta',
#   'ground beef',
#   'spaghetti',
#   'cake',
#   'energy drink',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['grated cheese',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['pancakes',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['frozen smoothie',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['carrots',
#   'green tea',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['chocolate',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['turkey',
#   'burgers',
#   'chocolate',
#   'olive oil',
#   'eggs',
#   'cooking oil',
#   'corn',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['frozen vegetables',
#   'tomatoes',
#   'pepper',
#   'spaghetti',
#   'mineral water',
#   'pancakes',
#   'chicken',
#   'chili',
#   'tea',
#   'french fries',
#   'tomato juice',
#   'fresh bread',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['cookies',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['ground beef',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['turkey',
#   'eggs',
#   'chocolate',
#   'frozen smoothie',
#   'tomato juice',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['frozen vegetables',
#   'cooking oil',
#   'mashed potato',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['frozen vegetables',
#   'ground beef',
#   'tomato sauce',
#   'mineral water',
#   'meatballs',
#   'olive oil',
#   'light cream',
#   'tomato juice',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['red wine',
#   'spaghetti',
#   'mineral water',
#   'soup',
#   'milk',
#   'eggs',
#   'cake',
#   'gums',
#   'cooking oil',
#   'chocolate',
#   'frozen smoothie',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['chocolate',
#   'tomatoes',
#   'spaghetti',
#   'mineral water',
#   'avocado',
#   'milk',
#   'olive oil',
#   'eggs',
#   'rice',
#   'french fries',
#   'brownies',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['chocolate',
#   'shrimp',
#   'pasta',
#   'frozen vegetables',
#   'ground beef',
#   'mineral water',
#   'nonfat milk',
#   'eggs',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['turkey',
#   'shrimp',
#   'pasta',
#   'pepper',
#   'spaghetti',
#   'mineral water',
#   'eggs',
#   'chicken',
#   'french fries',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['cookies',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['turkey',
#   'tomatoes',
#   'cake',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['yams',
#   'mineral water',
#   'soup',
#   'milk',
#   'pancakes',
#   'whole wheat rice',
#   'barbecue sauce',
#   'carrots',
#   'chocolate',
#   'champagne',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['rice',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['chocolate',
#   'milk',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['shrimp',
#   'pasta',
#   'frozen vegetables',
#   'water spray',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['burgers',
#   'mineral water',
#   'milk',
#   'eggs',
#   'whole wheat rice',
#   'mint',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['mineral water',
#   'vegetables mix',
#   'cake',
#   'frozen smoothie',
#   'brownies',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['cookies',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['shrimp',
#   'pasta',
#   'chicken',
#   'chocolate bread',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['shallot',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['shrimp',
#   'pasta',
#   'spaghetti',
#   'eggs',
#   'hot dogs',
#   'green tea',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['burgers',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['red wine',
#   'ground beef',
#   'spaghetti',
#   'mineral water',
#   'milk',
#   'olive oil',
#   'strong cheese',
#   'light cream',
#   'cooking oil',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['burgers',
#   'grated cheese',
#   'spaghetti',
#   'avocado',
#   'milk',
#   'oil',
#   'french fries',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['herb & pepper',
#   'whole wheat pasta',
#   'ground beef',
#   'mineral water',
#   'olive oil',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['shrimp',
#   'pasta',
#   'yams',
#   'milk',
#   'chocolate',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['butter',
#   'green tea',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['light mayo',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['low fat yogurt',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['herb & pepper',
#   'shrimp',
#   'pasta',
#   'spaghetti',
#   'milk',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['burgers',
#   'eggs',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['turkey',
#   'herb & pepper',
#   'ground beef',
#   'soup',
#   'avocado',
#   'milk',
#   'black tea',
#   'eggs',
#   'barbecue sauce',
#   'carrots',
#   'cookies',
#   'tomato juice',
#   'fresh bread',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['cookies',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['escalope',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['pepper',
#   'french fries',
#   'strawberries',
#   'pancakes',
#   'low fat yogurt',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['frozen vegetables',
#   'yams',
#   'chicken',
#   'honey',
#   'light mayo',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['chocolate',
#   'champagne',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['herb & pepper',
#   'honey',
#   'cake',
#   'rice',
#   'protein bar',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['burgers',
#   'chocolate',
#   'frozen vegetables',
#   'ground beef',
#   'mineral water',
#   'milk',
#   'light mayo',
#   'asparagus',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['chocolate',
#   'mineral water',
#   'corn',
#   'cottage cheese',
#   'green tea',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['muffins',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['ham',
#   'french wine',
#   'escalope',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['spaghetti',
#   'milk',
#   'whole wheat rice',
#   'mint green tea',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['chocolate',
#   'body spray',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['frozen vegetables',
#   'french fries',
#   'hot dogs',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['candy bars',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['burgers',
#   'shrimp',
#   'pasta',
#   'milk',
#   'green tea',
#   'french fries',
#   'cookies',
#   'white wine',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['parmesan cheese',
#   'ground beef',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['pancakes',
#   'whole wheat rice',
#   'candy bars',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['eggs',
#   'eggplant',
#   'cookies',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['frozen vegetables',
#   'mineral water',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['chocolate',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['turkey',
#   'spaghetti',
#   'milk',
#   'whole wheat rice',
#   'chocolate',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['whole wheat pasta',
#   'ground beef',
#   'spaghetti',
#   'soup',
#   'meatballs',
#   'chicken',
#   'blueberries',
#   'cooking oil',
#   'champagne',
#   'yogurt cake',
#   'protein bar',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['cooking oil',
#   'tomato juice',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['frozen vegetables',
#   'milk',
#   'eggs',
#   'french fries',
#   'green tea',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['fresh tuna',
#   'spaghetti',
#   'olive oil',
#   'french wine',
#   'eggs',
#   'french fries',
#   'champagne',
#   'pancakes',
#   'light mayo',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['red wine',
#   'honey',
#   'hot dogs',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['milk',
#   'bacon',
#   'eggs',
#   'french fries',
#   'fresh bread',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['french fries',
#   'yogurt cake',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['milk',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['french fries',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['chocolate',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['burgers',
#   'ham',
#   'red wine',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['shrimp',
#   'pasta',
#   'tomatoes',
#   'energy bar',
#   'french wine',
#   'antioxydant juice',
#   'french fries',
#   'frozen smoothie',
#   'brownies',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['green tea',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['low fat yogurt',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['turkey',
#   'spaghetti',
#   'mineral water',
#   'soup',
#   'spinach',
#   'soda',
#   'energy drink',
#   'salt',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['turkey',
#   'eggs',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['bug spray',
#   'hot dogs',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['oil',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['soup',
#   'energy bar',
#   'chicken',
#   'eggs',
#   'cake',
#   'french fries',
#   'body spray',
#   'strawberries',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['spaghetti',
#   'chocolate',
#   'yogurt cake',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['turkey',
#   'mineral water',
#   'meatballs',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['ground beef',
#   'mineral water',
#   'chocolate',
#   'fromage blanc',
#   'bacon',
#   'hot dogs',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['frozen vegetables',
#   'mineral water',
#   'vegetables mix',
#   'escalope',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['herb & pepper',
#   'red wine',
#   'tomatoes',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['whole wheat pasta',
#   'olive oil',
#   'cereals',
#   'brownies',
#   'green tea',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['cookies',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['olive oil',
#   'cookies',
#   'mushroom cream sauce',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['ground beef',
#   'pancakes',
#   'cooking oil',
#   'gluten free bar',
#   'light mayo',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['mineral water',
#   'french fries',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['herb & pepper',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['salmon',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['eggs',
#   'escalope',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['mineral water',
#   'tomato juice',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['mineral water',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['shrimp',
#   'mineral water',
#   'soup',
#   'black tea',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['cake',
#   'frozen smoothie',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['turkey',
#   'burgers',
#   'grated cheese',
#   'tomatoes',
#   'chocolate',
#   'fromage blanc',
#   'honey',
#   'whole wheat rice',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['frozen vegetables',
#   'ground beef',
#   'mineral water',
#   'olive oil',
#   'pancakes',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['turkey',
#   'burgers',
#   'ground beef',
#   'milk',
#   'olive oil',
#   'cake',
#   'fresh bread',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['whole wheat pasta',
#   'ground beef',
#   'spaghetti',
#   'yams',
#   'mineral water',
#   'soup',
#   'chutney',
#   'cereals',
#   'energy drink',
#   'protein bar',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['eggs',
#   'whole wheat rice',
#   'cake',
#   'green tea',
#   'escalope',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['ground beef',
#   'yams',
#   'soup',
#   'avocado',
#   'salmon',
#   'green tea',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['milk',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['spaghetti',
#   'chocolate',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['whole wheat pasta',
#   'honey',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['whole wheat pasta',
#   'green tea',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['spaghetti',
#   'meatballs',
#   'vegetables mix',
#   'chocolate',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
# ...
#   'nan',
#   'nan',
#   'nan'],
#  ['fresh tuna',
#   'frozen vegetables',
#   'chicken',
#   'fromage blanc',
#   'honey',
#   'light mayo',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['ground beef',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['muffins',
#   'champagne',
#   'cookies',
#   'fresh bread',
#   'green tea',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['frozen vegetables',
#   'spaghetti',
#   'chocolate',
#   'escalope',
#   'fresh bread',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['pickles',
#   'spaghetti',
#   'french fries',
#   'frozen smoothie',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['avocado',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['sandwich',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['spaghetti',
#   'milk',
#   'oil',
#   'shampoo',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['champagne',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['spaghetti',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['champagne',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['avocado',
#   'milk',
#   'butter',
#   'french fries',
#   'cookies',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['turkey',
#   'frozen vegetables',
#   'chicken',
#   'eggs',
#   'frozen smoothie',
#   'cauliflower',
#   'low fat yogurt',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['burgers',
#   'shrimp',
#   'tomatoes',
#   'milk',
#   'energy bar',
#   'almonds',
#   'chicken',
#   'chocolate',
#   'french fries',
#   'body spray',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['burgers',
#   'milk',
#   'cake',
#   'cooking oil',
#   'french fries',
#   'escalope',
#   'zucchini',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['tomatoes',
#   'spaghetti',
#   'chocolate',
#   'milk',
#   'olive oil',
#   'whole wheat rice',
#   'cake',
#   'frozen smoothie',
#   'protein bar',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['fresh tuna',
#   'red wine',
#   'pepper',
#   'spaghetti',
#   'fromage blanc',
#   'salmon',
#   'pancakes',
#   'eggs',
#   'honey',
#   'green tea',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['milk',
#   'low fat yogurt',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['shrimp',
#   'parmesan cheese',
#   'soup',
#   'chocolate',
#   'brownies',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['spaghetti',
#   'chicken',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['grated cheese',
#   'vegetables mix',
#   'nonfat milk',
#   'green tea',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['fresh tuna',
#   'parmesan cheese',
#   'cider',
#   'muffins',
#   'spinach',
#   'honey',
#   'oil',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['cake',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['shrimp',
#   'chocolate',
#   'mushroom cream sauce',
#   'candy bars',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['candy bars',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['avocado',
#   'honey',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['shrimp',
#   'frozen vegetables',
#   'tomatoes',
#   'cottage cheese',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['french fries',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['strawberries',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['ground beef',
#   'almonds',
#   'french fries',
#   'escalope',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['grated cheese',
#   'spaghetti',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['turkey',
#   'mineral water',
#   'butter',
#   'frozen smoothie',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['frozen vegetables',
#   'spaghetti',
#   'french fries',
#   'light mayo',
#   'green tea',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['burgers',
#   'ham',
#   'spaghetti',
#   'whole wheat rice',
#   'eggplant',
#   'chocolate',
#   'cookies',
#   'shallot',
#   'green tea',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['grated cheese',
#   'frozen vegetables',
#   'spaghetti',
#   'avocado',
#   'milk',
#   'blueberries',
#   'light cream',
#   'rice',
#   'green tea',
#   'chocolate',
#   'french fries',
#   'frozen smoothie',
#   'cookies',
#   'hot dogs',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['burgers',
#   'shrimp',
#   'tomatoes',
#   'bacon',
#   'whole wheat rice',
#   'green tea',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['parmesan cheese',
#   'pancakes',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['parmesan cheese',
#   'cake',
#   'hot dogs',
#   'green tea',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['spaghetti',
#   'milk',
#   'fromage blanc',
#   'ketchup',
#   'chocolate',
#   'babies food',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['mint',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['chocolate',
#   'mint',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['butter',
#   'french fries',
#   'salt',
#   'fresh bread',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['chocolate',
#   'french fries',
#   'strawberries',
#   'yogurt cake',
#   'light mayo',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['eggs',
#   'eggplant',
#   'cookies',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['yogurt cake',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['herb & pepper',
#   'spaghetti',
#   'meatballs',
#   'milk',
#   'olive oil',
#   'chicken',
#   'honey',
#   'frozen smoothie',
#   'escalope',
#   'pancakes',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['frozen vegetables',
#   'rice',
#   'chocolate',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['herb & pepper',
#   'ground beef',
#   'spaghetti',
#   'chocolate',
#   'milk',
#   'eggs',
#   'light cream',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['eggs',
#   'champagne',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['whole wheat pasta',
#   'ground beef',
#   'olive oil',
#   'blueberries',
#   'escalope',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['burgers',
#   'red wine',
#   'mineral water',
#   'eggs',
#   'oil',
#   'carrots',
#   'hand protein bar',
#   'tomato juice',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['chocolate',
#   'grated cheese',
#   'herb & pepper',
#   'mineral water',
#   'soup',
#   'olive oil',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['burgers',
#   'shrimp',
#   'mineral water',
#   'chicken',
#   'fromage blanc',
#   'salmon',
#   'eggs',
#   'cake',
#   'frozen smoothie',
#   'strawberries',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['green tea',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['cookies',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['french fries',
#   'cookies',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['milk',
#   'butter',
#   'eggs',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['eggs',
#   'mushroom cream sauce',
#   'low fat yogurt',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['eggs',
#   'green tea',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['mineral water',
#   'whole wheat rice',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['shrimp',
#   'frozen vegetables',
#   'parmesan cheese',
#   'mineral water',
#   'whole wheat rice',
#   'cake',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['whole wheat rice',
#   'pancakes',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['frozen vegetables',
#   'spaghetti',
#   'olive oil',
#   'butter',
#   'salmon',
#   'oil',
#   'cooking oil',
#   'frozen smoothie',
#   'cauliflower',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['green tea',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['fresh tuna',
#   'eggs',
#   'escalope',
#   'strawberries',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['spaghetti',
#   'soup',
#   'milk',
#   'carrots',
#   'chocolate',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['burgers',
#   'mineral water',
#   'soup',
#   'meatballs',
#   'olive oil',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['grated cheese',
#   'mineral water',
#   'cooking oil',
#   'french fries',
#   'cookies',
#   'low fat yogurt',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['shrimp',
#   'milk',
#   'olive oil',
#   'french fries',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['frozen vegetables',
#   'mineral water',
#   'pancakes',
#   'cake',
#   'tomato juice',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['spaghetti',
#   'milk',
#   'chicken',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['grated cheese',
#   'mineral water',
#   'chicken',
#   'french fries',
#   'cottage cheese',
#   'pancakes',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['ground beef',
#   'mineral water',
#   'milk',
#   'eggs',
#   'mint',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['shrimp',
#   'body spray',
#   'green tea',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['frozen smoothie',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['herb & pepper',
#   'frozen vegetables',
#   'mineral water',
#   'muffins',
#   'cereals',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['turkey',
#   'tomatoes',
#   'spaghetti',
#   'milk',
#   'cider',
#   'eggs',
#   'honey',
#   'cake',
#   'green tea',
#   'french fries',
#   'brownies',
#   'tomato juice',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ...]

# %%
#Removing NaN values from the record and saving it to new_record
new_record = []
for p in record:
  z = [x for x in p if x != 'nan']
  new_record.append(z)
print(new_record)
# Out:
# [['shrimp', 'almonds', 'avocado', 'vegetables mix', 'green grapes', 'whole weat flour', 'yams', 'cottage cheese', 'energy drink', 'tomato juice', 'low fat yogurt', 'green tea', 'honey', 'salad', 'mineral water', 'salmon', 'antioxydant juice', 'frozen smoothie', 'spinach', 'olive oil'], ['burgers', 'meatballs', 'eggs'], ['chutney'], ['turkey', 'avocado'], ['mineral water', 'milk', 'energy bar', 'whole wheat rice', 'green tea'], ['low fat yogurt'], ['whole wheat pasta', 'french fries'], ['soup', 'light cream', 'shallot'], ['frozen vegetables', 'spaghetti', 'green tea'], ['french fries'], ['eggs', 'pet food'], ['cookies'], ['turkey', 'burgers', 'mineral water', 'eggs', 'cooking oil'], ['spaghetti', 'champagne', 'cookies'], ['mineral water', 'salmon'], ['mineral water'], ['shrimp', 'chocolate', 'chicken', 'honey', 'oil', 'cooking oil', 'low fat yogurt'], ['turkey', 'eggs'], ['turkey', 'fresh tuna', 'tomatoes', 'spaghetti', 'mineral water', 'black tea', 'salmon', 'eggs', 'chicken', 'extra dark chocolate'], ['meatballs', 'milk', 'honey', 'french fries', 'protein bar'], ['red wine', 'shrimp', 'pasta', 'pepper', 'eggs', 'chocolate', 'shampoo'], ['rice', 'sparkling water'], ['spaghetti', 'mineral water', 'ham', 'body spray', 'pancakes', 'green tea'], ['burgers', 'grated cheese', 'shrimp', 'pasta', 'avocado', 'honey', 'white wine', 'toothpaste'], ['eggs'], ['parmesan cheese', 'spaghetti', 'soup', 'avocado', 'milk', 'fresh bread'], ['ground beef', 'spaghetti', 'mineral water', 'milk', 'energy bar', 'black tea', 'salmon', 'frozen smoothie', 'escalope'], ['sparkling water'], ['mineral water', 'eggs', 'chicken', 'chocolate', 'french fries'], ['frozen vegetables', 'spaghetti', 'yams', 'mineral water'], ['herb & pepper', 'tomato sauce', 'light cream', 'magazines'], ['mineral water', 'chocolate', 'avocado', 'eggs'], ['turkey', 'french fries', 'strawberries'], ['frozen vegetables', 'strong cheese', 'chocolate'], ['cookies'], ['pickles', 'spaghetti', 'salmon', 'escalope'], ['energy bar', 'french fries'], ['red wine', 'ground beef', 'mineral water'], ['mineral water', 'cake', 'cottage cheese'], ['pickles', 'champagne', 'green tea'], ['spaghetti'], ['fresh tuna', 'frozen vegetables', 'spaghetti', 'mineral water', 'honey', 'whole wheat rice', 'frozen smoothie', 'escalope'], ['spaghetti'], ['soup', 'meatballs', 'hot dogs', 'sparkling water'], ['escalope'], ['soup', 'avocado', 'french fries', 'hot dogs', 'brownies', 'body spray', 'pancakes', 'green tea'], ['mineral water', 'chicken', 'cereals', 'clothes accessories'], ['mineral water', 'bug spray'], ['avocado', 'muffins'], ['burgers', 'black tea', 'green tea'], ['spaghetti', 'chocolate', 'brownies', 'white wine', 'green tea'], ['fresh tuna', 'mineral water', 'eggs'], ['spaghetti', 'muffins'], ['spaghetti', 'chocolate'], ['french fries', 'escalope', 'champagne'], ['tomato sauce', 'light mayo'], ['turkey', 'fresh tuna', 'frozen vegetables', 'tomatoes', 'ground beef', 'spaghetti', 'mineral water', 'chocolate', 'soup', 'milk', 'olive oil'], ['eggs', 'cookies'], ['soup', 'chicken', 'gums', 'soda', 'body spray', 'energy drink', 'green tea'], ['turkey', 'frozen vegetables', 'mineral water', 'cider', 'cooking oil', 'green tea'], ['spaghetti'], ['clothes accessories'], ['energy drink'], ['soup', 'bug spray', 'shallot', 'protein bar', 'green tea'], ['turkey', 'eggs'], ['french fries'], ['chocolate', 'milk'], ['herb & pepper', 'whole wheat pasta', 'ground beef', 'mineral water', 'avocado', 'cider', 'whole wheat rice'], ['cookies'], ['shrimp', 'pasta'], ['grated cheese', 'herb & pepper', 'tomatoes', 'tomato sauce', 'corn'], ['burgers', 'escalope', 'shallot'], ['cookies'], ['yogurt cake'], ['soup', 'eggs'], ['cookies'], ['mineral water', 'chocolate', 'low fat yogurt'], ['eggs', 'strawberries'], ['grated cheese', 'ground beef', 'spaghetti', 'mineral water', 'white wine'], ['mint'], ['eggs', 'cake', 'french fries'], ['burgers', 'spaghetti', 'milk', 'french fries', 'green tea'], ['mineral water', 'energy bar', 'butt ...

# %%
#Converting list of list to list of sets of Transaction
k = []
for i in new_record:
  z = set(i)
  k.append(z)

# %%
k
# Out:
# [{'almonds',
#   'antioxydant juice',
#   'avocado',
#   'cottage cheese',
#   'energy drink',
#   'frozen smoothie',
#   'green grapes',
#   'green tea',
#   'honey',
#   'low fat yogurt',
#   'mineral water',
#   'olive oil',
#   'salad',
#   'salmon',
#   'shrimp',
#   'spinach',
#   'tomato juice',
#   'vegetables mix',
#   'whole weat flour',
#   'yams'},
#  {'burgers', 'eggs', 'meatballs'},
#  {'chutney'},
#  {'avocado', 'turkey'},
#  {'energy bar', 'green tea', 'milk', 'mineral water', 'whole wheat rice'},
#  {'low fat yogurt'},
#  {'french fries', 'whole wheat pasta'},
#  {'light cream', 'shallot', 'soup'},
#  {'frozen vegetables', 'green tea', 'spaghetti'},
#  {'french fries'},
#  {'eggs', 'pet food'},
#  {'cookies'},
#  {'burgers', 'cooking oil', 'eggs', 'mineral water', 'turkey'},
#  {'champagne', 'cookies', 'spaghetti'},
#  {'mineral water', 'salmon'},
#  {'mineral water'},
#  {'chicken',
#   'chocolate',
#   'cooking oil',
#   'honey',
#   'low fat yogurt',
#   'oil',
#   'shrimp'},
#  {'eggs', 'turkey'},
#  {'black tea',
#   'chicken',
#   'eggs',
#   'extra dark chocolate',
#   'fresh tuna',
#   'mineral water',
#   'salmon',
#   'spaghetti',
#   'tomatoes',
#   'turkey'},
#  {'french fries', 'honey', 'meatballs', 'milk', 'protein bar'},
#  {'chocolate', 'eggs', 'pasta', 'pepper', 'red wine', 'shampoo', 'shrimp'},
#  {'rice', 'sparkling water'},
#  {'body spray', 'green tea', 'ham', 'mineral water', 'pancakes', 'spaghetti'},
#  {'avocado',
#   'burgers',
#   'grated cheese',
#   'honey',
#   'pasta',
#   'shrimp',
#   'toothpaste',
#   'white wine'},
#  {'eggs'},
#  {'avocado', 'fresh bread', 'milk', 'parmesan cheese', 'soup', 'spaghetti'},
#  {'black tea',
#   'energy bar',
#   'escalope',
#   'frozen smoothie',
#   'ground beef',
#   'milk',
#   'mineral water',
#   'salmon',
#   'spaghetti'},
#  {'sparkling water'},
#  {'chicken', 'chocolate', 'eggs', 'french fries', 'mineral water'},
#  {'frozen vegetables', 'mineral water', 'spaghetti', 'yams'},
#  {'herb & pepper', 'light cream', 'magazines', 'tomato sauce'},
#  {'avocado', 'chocolate', 'eggs', 'mineral water'},
#  {'french fries', 'strawberries', 'turkey'},
#  {'chocolate', 'frozen vegetables', 'strong cheese'},
#  {'cookies'},
#  {'escalope', 'pickles', 'salmon', 'spaghetti'},
#  {'energy bar', 'french fries'},
#  {'ground beef', 'mineral water', 'red wine'},
#  {'cake', 'cottage cheese', 'mineral water'},
#  {'champagne', 'green tea', 'pickles'},
#  {'spaghetti'},
#  {'escalope',
#   'fresh tuna',
#   'frozen smoothie',
#   'frozen vegetables',
#   'honey',
#   'mineral water',
#   'spaghetti',
#   'whole wheat rice'},
#  {'spaghetti'},
#  {'hot dogs', 'meatballs', 'soup', 'sparkling water'},
#  {'escalope'},
#  {'avocado',
#   'body spray',
#   'brownies',
#   'french fries',
#   'green tea',
#   'hot dogs',
#   'pancakes',
#   'soup'},
#  {'cereals', 'chicken', 'clothes accessories', 'mineral water'},
#  {'bug spray', 'mineral water'},
#  {'avocado', 'muffins'},
#  {'black tea', 'burgers', 'green tea'},
#  {'brownies', 'chocolate', 'green tea', 'spaghetti', 'white wine'},
#  {'eggs', 'fresh tuna', 'mineral water'},
#  {'muffins', 'spaghetti'},
#  {'chocolate', 'spaghetti'},
#  {'champagne', 'escalope', 'french fries'},
#  {'light mayo', 'tomato sauce'},
#  {'chocolate',
#   'fresh tuna',
#   'frozen vegetables',
#   'ground beef',
#   'milk',
#   'mineral water',
#   'olive oil',
#   'soup',
#   'spaghetti',
#   'tomatoes',
#   'turkey'},
#  {'cookies', 'eggs'},
#  {'body spray',
#   'chicken',
#   'energy drink',
#   'green tea',
#   'gums',
#   'soda',
#   'soup'},
#  {'cider',
#   'cooking oil',
#   'frozen vegetables',
#   'green tea',
#   'mineral water',
#   'turkey'},
#  {'spaghetti'},
#  {'clothes accessories'},
#  {'energy drink'},
#  {'bug spray', 'green tea', 'protein bar', 'shallot', 'soup'},
#  {'eggs', 'turkey'},
#  {'french fries'},
#  {'chocolate', 'milk'},
#  {'avocado',
#   'cider',
#   'ground beef',
#   'herb & pepper',
#   'mineral water',
#   'whole wheat pasta',
#   'whole wheat rice'},
#  {'cookies'},
#  {'pasta', 'shrimp'},
#  {'corn', 'grated cheese', 'herb & pepper', 'tomato sauce', 'tomatoes'},
#  {'burgers', 'escalope', 'shallot'},
#  {'cookies'},
#  {'yogurt cake'},
#  {'eggs', 'soup'},
#  {'cookies'},
#  {'chocolate', 'low fat yogurt', 'mineral water'},
#  {'eggs', 'strawberries'},
#  {'grated cheese', 'ground beef', 'mineral water', 'spaghetti', 'white wine'},
#  {'mint'},
#  {'cake', 'eggs', 'french fries'},
#  {'burgers', 'french fries', 'green tea', 'milk', 'spaghetti'},
#  {'butter', 'energy bar', 'french fries', 'mineral water'},
#  {'burgers',
#   'cooking oil',
#   'eggs',
#   'grated cheese',
#   'herb & pepper',
#   'mineral water'},
#  {'energy bar'},
#  {'energy bar', 'energy drink'},
#  {'chocolate', 'frozen smoothie'},
#  {'low fat yogurt'},
#  {'asparagus', 'salad'},
#  {'burgers', 'french fries', 'green tea', 'low fat yogurt'},
#  {'low fat yogurt'},
#  {'burgers',
#   'eggs',
#   'energy bar',
#   'french wine',
#   'herb & pepper',
#   'meatballs',
#   'mineral water',
#   'olive oil',
#   'pasta',
#   'salt',
#   'shrimp',
#   'spaghetti'},
#  {'champagne', 'low fat yogurt'},
#  {'champagne'},
#  {'almonds', 'burgers', 'cookies', 'eggs', 'french fries', 'green tea'},
#  {'body spray', 'escalope', 'ham', 'soup'},
#  {'extra dark chocolate',
#   'frozen vegetables',
#   'ham',
#   'magazines',
#   'oil',
#   'pepper',
#   'tea',
#   'turkey'},
#  {'cookies', 'eggs', 'muffins'},
#  {'cookies'},
#  {'chocolate',
#   'frozen vegetables',
#   'green tea',
#   'ground beef',
#   'spaghetti',
#   'whole wheat pasta'},
#  {'barbecue sauce', 'chocolate', 'mineral water'},
#  {'almonds',
#   'burgers',
#   'corn',
#   'eggs',
#   'energy bar',
#   'herb & pepper',
#   'mayonnaise',
#   'zucchini'},
#  {'almonds',
#   'burgers',
#   'chocolate',
#   'cottage cheese',
#   'eggs',
#   'ground beef',
#   'hot dogs',
#   'soup',
#   'turkey'},
#  {'chocolate', 'eggs', 'ham', 'spaghetti'},
#  {'carrots', 'energy bar', 'ground beef', 'pet food', 'protein bar'},
#  {'almonds',
#   'eggs',
#   'ground beef',
#   'mineral water',
#   'spaghetti',
#   'tomato sauce'},
#  {'cooking oil', 'gums', 'mineral water', 'olive oil'},
#  {'avocado',
#   'bug spray',
#   'eggs',
#   'green grapes',
#   'milk',
#   'mineral water',
#   'olive oil',
#   'pasta',
#   'shrimp',
#   'soup'},
#  {'cake',
#   'chicken',
#   'cooking oil',
#   'light mayo',
#   'low fat yogurt',
#   'pasta',
#   'shrimp',
#   'soup'},
#  {'champagne',
#   'chocolate',
#   'escalope',
#   'french fries',
#   'fresh bread',
#   'mineral water',
#   'mushroom cream sauce',
#   'spaghetti'},
#  {'eggs', 'mineral water', 'pasta', 'shrimp'},
#  {'burgers', 'fresh bread', 'oil', 'tomato juice'},
#  {'chocolate', 'eggs', 'french wine', 'low fat yogurt'},
#  {'chicken', 'eggs', 'french fries', 'pancakes'},
#  {'candy bars', 'herb & pepper', 'salmon', 'turkey', 'white wine'},
#  {'eggs',
#   'french fries',
#   'grated cheese',
#   'green tea',
#   'olive oil',
#   'spaghetti'},
#  {'energy bar', 'mineral water'},
#  {'eggs', 'french fries'},
#  {'almonds',
#   'burgers',
#   'chocolate',
#   'eggs',
#   'milk',
#   'mineral water',
#   'soup',
#   'tomato juice',
#   'tomatoes'},
#  {'muffins'},
#  {'pasta'},
#  {'frozen smoothie', 'spaghetti', 'tomatoes'},
#  {'ground beef', 'milk', 'spaghetti'},
#  {'french fries'},
#  {'chocolate', 'milk'},
#  {'burgers',
#   'chocolate',
#   'eggs',
#   'french fries',
#   'frozen vegetables',
#   'low fat yogurt',
#   'milk',
#   'mineral water',
#   'pancakes',
#   'pasta',
#   'shrimp',
#   'spaghetti'},
#  {'antioxydant juice', 'ground beef', 'mineral water', 'protein bar'},
#  {'cake',
#   'energy drink',
#   'grated cheese',
#   'ground beef',
#   'spaghetti',
#   'whole wheat pasta'},
#  {'grated cheese'},
#  {'pancakes'},
#  {'frozen smoothie'},
#  {'carrots', 'green tea'},
#  {'chocolate'},
#  {'burgers',
#   'chocolate',
#   'cooking oil',
#   'corn',
#   'eggs',
#   'olive oil',
#   'turkey'},
#  {'chicken',
#   'chili',
#   'french fries',
#   'fresh bread',
#   'frozen vegetables',
#   'mineral water',
#   'pancakes',
#   'pepper',
#   'spaghetti',
#   'tea',
#   'tomato juice',
#   'tomatoes'},
#  {'cookies'},
#  {'ground beef'},
#  {'chocolate', 'eggs', 'frozen smoothie', 'tomato juice', 'turkey'},
#  {'cooking oil', 'frozen vegetables', 'mashed potato'},
#  {'frozen vegetables',
#   'ground beef',
#   'light cream',
#   'meatballs',
#   'mineral water',
#   'olive oil',
#   'tomato juice',
#   'tomato sauce'},
#  {'cake',
#   'chocolate',
#   'cooking oil',
#   'eggs',
#   'frozen smoothie',
#   'gums',
#   'milk',
#   'mineral water',
#   'red wine',
#   'soup',
#   'spaghetti'},
#  {'avocado',
#   'brownies',
#   'chocolate',
#   'eggs',
#   'french fries',
#   'milk',
#   'mineral water',
#   'olive oil',
#   'rice',
#   'spaghetti',
#   'tomatoes'},
#  {'chocolate',
#   'eggs',
#   'frozen vegetables',
#   'ground beef',
#   'mineral water',
#   'nonfat milk',
#   'pasta',
#   'shrimp'},
#  {'chicken',
#   'eggs',
#   'french fries',
#   'mineral water',
#   'pasta',
#   'pepper',
#   'shrimp',
#   'spaghetti',
#   'turkey'},
#  {'cookies'},
#  {'cake', 'tomatoes', 'turkey'},
#  {'barbecue sauce',
#   'carrots',
#   'champagne',
#   'chocolate',
#   'milk',
#   'mineral water',
#   'pancakes',
#   'soup',
#   'whole wheat rice',
#   'yams'},
#  {'rice'},
#  {'chocolate', 'milk'},
#  {'frozen vegetables', 'pasta', 'shrimp', 'water spray'},
#  {'burgers', 'eggs', 'milk', 'mineral water', 'mint', 'whole wheat rice'},
#  {'brownies', 'cake', 'frozen smoothie', 'mineral water', 'vegetables mix'},
#  {'cookies'},
#  {'chicken', 'chocolate bread', 'pasta', 'shrimp'},
#  {'shallot'},
#  {'eggs', 'green tea', 'hot dogs', 'pasta', 'shrimp', 'spaghetti'},
#  {'burgers'},
#  {'cooking oil',
#   'ground beef',
#   'light cream',
#   'milk',
#   'mineral water',
#   'olive oil',
#   'red wine',
#   'spaghetti',
#   'strong cheese'},
#  {'avocado',
#   'burgers',
#   'french fries',
#   'grated cheese',
#   'milk',
#   'oil',
#   'spaghetti'},
#  {'ground beef',
#   'herb & pepper',
#   'mineral water',
#   'olive oil',
#   'whole wheat pasta'},
#  {'chocolate', 'milk', 'pasta', 'shrimp', 'yams'},
#  {'butter', 'green tea'},
#  {'light mayo'},
#  {'low fat yogurt'},
#  {'herb & pepper', 'milk', 'pasta', 'shrimp', 'spaghetti'},
#  {'burgers', 'eggs'},
#  {'avocado',
#   'barbecue sauce',
#   'black tea',
#   'carrots',
#   'cookies',
#   'eggs',
#   'fresh bread',
#   'ground beef',
#   'herb & pepper',
#   'milk',
#   'soup',
#   'tomato juice',
#   'turkey'},
#  {'cookies'},
#  {'escalope'},
#  {'french fries', 'low fat yogurt', 'pancakes', 'pepper', 'strawberries'},
#  {'chicken', 'frozen vegetables', 'honey', 'light mayo', 'yams'},
#  {'champagne', 'chocolate'},
#  {'cake', 'herb & pepper', 'honey', 'protein bar', 'rice'},
#  {'asparagus',
#   'burgers',
#   'chocolate',
#   'frozen vegetables',
#   'ground beef',
#   'light mayo',
#   'milk',
#   'mineral water'},
#  {'chocolate', 'corn', 'cottage cheese', 'green tea', 'mineral water'},
#  {'muffins'},
#  {'escalope', 'french wine', 'ham'},
#  {'milk', 'mint green tea', 'spaghetti', 'whole wheat rice'},
#  {'body spray', 'chocolate'},
#  {'french fries', 'frozen vegetables', 'hot dogs'},
#  {'candy bars'},
#  {'burgers',
#   'cookies',
#   'french fries',
#   'green tea',
#   'milk',
#   'pasta',
#   'shrimp',
#   'white wine'},
#  {'ground beef', 'parmesan cheese'},
#  {'candy bars', 'pancakes', 'whole wheat rice'},
#  {'cookies', 'eggplant', 'eggs'},
#  {'frozen vegetables', 'mineral water'},
#  {'chocolate'},
#  {'chocolate', 'milk', 'spaghetti', 'turkey', 'whole wheat rice'},
#  {'blueberries',
#   'champagne',
#   'chicken',
#   'cooking oil',
#   'ground beef',
#   'meatballs',
#   'protein bar',
#   'soup',
#   'spaghetti',
#   'whole wheat pasta',
#   'yogurt cake'},
#  {'cooking oil', 'tomato juice'},
#  {'eggs', 'french fries', 'frozen vegetables', 'green tea', 'milk'},
#  {'champagne',
#   'eggs',
#   'french fries',
#   'french wine',
#   'fresh tuna',
#   'light mayo',
#   'olive oil',
#   'pancakes',
#   'spaghetti'},
#  {'honey', 'hot dogs', 'red wine'},
#  {'bacon', 'eggs', 'french fries', 'fresh bread', 'milk'},
#  {'french fries', 'yogurt cake'},
#  {'milk'},
#  {'french fries'},
#  {'chocolate'},
#  {'burgers', 'ham', 'red wine'},
#  {'antioxydant juice',
#   'brownies',
#   'energy bar',
#   'french fries',
#   'french wine',
#   'frozen smoothie',
#   'pasta',
#   'shrimp',
#   'tomatoes'},
#  {'green tea'},
#  {'low fat yogurt'},
#  {'energy drink',
#   'mineral water',
#   'salt',
#   'soda',
#   'soup',
#   'spaghetti',
#   'spinach',
#   'turkey'},
#  {'eggs', 'turkey'},
#  {'bug spray', 'hot dogs'},
#  {'oil'},
#  {'body spray',
#   'cake',
#   'chicken',
#   'eggs',
#   'energy bar',
#   'french fries',
#   'soup',
#   'strawberries'},
#  {'chocolate', 'spaghetti', 'yogurt cake'},
#  {'meatballs', 'mineral water', 'turkey'},
#  {'bacon',
#   'chocolate',
#   'fromage blanc',
#   'ground beef',
#   'hot dogs',
#   'mineral water'},
#  {'escalope', 'frozen vegetables', 'mineral water', 'vegetables mix'},
#  {'herb & pepper', 'red wine', 'tomatoes'},
#  {'brownies', 'cereals', 'green tea', 'olive oil', 'whole wheat pasta'},
#  {'cookies'},
#  {'cookies', 'mushroom cream sauce', 'olive oil'},
#  {'cooking oil', 'gluten free bar', 'ground beef', 'light mayo', 'pancakes'},
#  {'french fries', 'mineral water'},
#  {'herb & pepper'},
#  {'salmon'},
#  {'eggs', 'escalope'},
#  {'mineral water', 'tomato juice'},
#  {'mineral water'},
#  {'black tea', 'mineral water', 'shrimp', 'soup'},
#  {'cake', 'frozen smoothie'},
#  {'burgers',
#   'chocolate',
#   'fromage blanc',
#   'grated cheese',
#   'honey',
#   'tomatoes',
#   'turkey',
#   'whole wheat rice'},
#  {'frozen vegetables',
#   'ground beef',
#   'mineral water',
#   'olive oil',
#   'pancakes'},
#  {'burgers',
#   'cake',
#   'fresh bread',
#   'ground beef',
#   'milk',
#   'olive oil',
#   'turkey'},
#  {'cereals',
#   'chutney',
#   'energy drink',
#   'ground beef',
#   'mineral water',
#   'protein bar',
#   'soup',
#   'spaghetti',
#   'whole wheat pasta',
#   'yams'},
#  {'cake', 'eggs', 'escalope', 'green tea', 'whole wheat rice'},
#  {'avocado', 'green tea', 'ground beef', 'salmon', 'soup', 'yams'},
#  {'milk'},
#  {'chocolate', 'spaghetti'},
#  {'honey', 'whole wheat pasta'},
#  {'green tea', 'whole wheat pasta'},
#  {'chocolate', 'meatballs', 'spaghetti', 'vegetables mix'},
#  {'eggs', 'low fat yogurt'},
#  {'brownies',
#   'cake',
#   'eggs',
#   'fresh tuna',
#   'mineral water',
#   'olive oil',
#   'pasta',
#   'shrimp',
#   'tomato juice'},
#  {'fresh bread', 'green grapes', 'hot dogs', 'mineral water'},
#  {'chocolate', 'eggs', 'frozen vegetables', 'meatballs'},
#  {'chocolate'},
#  {'meatballs', 'milk'},
#  {'low fat yogurt'},
#  {'green tea'},
#  {'escalope', 'pasta'},
#  {'chocolate',
#   'french wine',
#   'fresh bread',
#   'light mayo',
#   'magazines',
#   'olive oil',
#   'pepper',
#   'rice',
#   'salmon'},
#  {'clothes accessories',
#   'french wine',
#   'green tea',
#   'hot dogs',
#   'red wine',
#   'rice',
#   'vegetables mix'},
#  {'burgers',
#   'cake',
#   'chicken',
#   'dessert wine',
#   'green tea',
#   'protein bar',
#   'spaghetti'},
#  {'cake', 'french wine', 'fresh bread'},
#  {'burgers', 'eggs', 'flax seed', 'frozen vegetables'},
#  {'red wine'},
#  {'energy bar', 'green grapes', 'mineral water', 'pepper'},
#  {'cake', 'chocolate', 'eggs', 'french fries', 'green tea', 'milk'},
#  {'french fries'},
#  {'almonds'},
#  {'burgers', 'green tea', 'mineral water'},
#  {'milk', 'pancakes'},
#  {'eggs', 'pancakes', 'salt', 'tomato juice'},
#  {'mineral water'},
#  {'ham', 'mineral water', 'olive oil', 'spaghetti'},
#  {'fresh bread', 'salt', 'tomato juice'},
#  {'mushroom cream sauce', 'spaghetti'},
#  {'eggs', 'mineral water', 'pet food', 'spaghetti'},
#  {'frozen vegetables', 'spaghetti'},
#  {'energy drink'},
#  {'muffins'},
#  {'milk', 'turkey'},
#  {'cookies'},
#  {'chocolate'},
#  {'chocolate',
#   'cooking oil',
#   'eggs',
#   'escalope',
#   'mineral water',
#   'spaghetti'},
#  {'frozen vegetables', 'green tea', 'pepper', 'shrimp', 'spaghetti'},
#  {'burgers',
#   'french fries',
#   'fresh tuna',
#   'hand protein bar',
#   'low fat yogurt',
#   'mineral water',
#   'red wine'},
#  {'eggs', 'energy drink', 'fresh bread', 'pancakes'},
#  {'french fries',
#   'frozen smoothie',
#   'green tea',
#   'hot dogs',
#   'salmon',
#   'strong cheese'},
#  {'frozen smoothie',
#   'grated cheese',
#   'milk',
#   'pasta',
#   'sandwich',
#   'shrimp',
#   'tomatoes'},
#  {'eggs', 'herb & pepper', 'olive oil', 'pancakes', 'whole wheat pasta'},
#  {'antioxydant juice', 'spaghetti'},
#  {'almonds', 'chocolate', 'eggs', 'milk', 'strawberries', 'white wine'},
#  {'french fries', 'strawberries'},
#  {'mineral water'},
#  {'eggs'},
#  {'escalope'},
#  {'cake'},
#  {'antioxydant juice', 'body spray', 'green tea', 'whole wheat pasta'},
#  {'frozen smoothie', 'mineral water', 'oil'},
#  {'champagne', 'french fries'},
#  {'chocolate', 'french fries'},
#  {'eggs', 'frozen vegetables', 'spaghetti'},
#  {'hot dogs'},
#  {'chocolate', 'cookies'},
#  {'pancakes'},
#  {'butter', 'chicken', 'salmon', 'shrimp'},
#  {'babies food', 'chocolate', 'cookies'},
#  {'cake', 'chocolate', 'french fries', 'fresh bread', 'pepper', 'spaghetti'},
#  {'avocado', 'cereals', 'french fries', 'oil'},
#  {'cooking oil',
#   'eggs',
#   'green tea',
#   'herb & pepper',
#   'low fat yogurt',
#   'mineral water',
#   'oil',
#   'shampoo',
#   'spaghetti',
#   'spinach',
#   'tomato juice'},
#  {'french fries',
#   'frozen vegetables',
#   'ground beef',
#   'herb & pepper',
#   'mint green tea',
#   'pepper',
#   'spaghetti'},
#  {'french fries'},
#  {'green tea', 'tomato juice'},
#  {'chocolate', 'eggs', 'whole wheat rice'},
#  {'cooking oil',
#   'eggs',
#   'grated cheese',
#   'green tea',
#   'herb & pepper',
#   'mineral water',
#   'red wine',
#   'salmon',
#   'spaghetti'},
#  {'cookies',
#   'french fries',
#   'fresh bread',
#   'low fat yogurt',
#   'shallot',
#   'tomato juice'},
#  {'burgers', 'fresh tuna', 'honey', 'muffins', 'spaghetti'},
#  {'chicken', 'eggs', 'ground beef', 'herb & pepper', 'spaghetti'},
#  {'grated cheese', 'mayonnaise', 'muffins', 'tomato juice'},
#  {'energy drink',
#   'frozen smoothie',
#   'hot dogs',
#   'mineral water',
#   'muffins',
#   'whole wheat pasta',
#   'yams'},
#  {'blueberries',
#   'burgers',
#   'eggs',
#   'milk',
#   'olive oil',
#   'salmon',
#   'soup',
#   'spaghetti'},
#  {'champagne', 'chocolate', 'magazines'},
#  {'chocolate',
#   'french wine',
#   'frozen vegetables',
#   'green grapes',
#   'mineral water',
#   'rice',
#   'spaghetti',
#   'yams'},
#  {'chocolate', 'tomato sauce'},
#  {'eggs', 'milk'},
#  {'pet food'},
#  {'yogurt cake'},
#  {'green tea'},
#  {'escalope', 'pasta'},
#  {'ground beef', 'herb & pepper'},
#  {'brownies', 'honey', 'mineral water'},
#  {'cake', 'eggs', 'energy drink', 'turkey'},
#  {'burgers',
#   'candy bars',
#   'dessert wine',
#   'eggs',
#   'ground beef',
#   'gums',
#   'salmon',
#   'soup',
#   'tomato juice',
#   'turkey'},
#  {'chicken', 'mineral water', 'spaghetti'},
#  {'carrots', 'french fries', 'ground beef', 'melons', 'turkey'},
#  {'eggs', 'low fat yogurt', 'mineral water'},
#  {'cooking oil', 'shampoo', 'turkey'},
#  {'hot dogs', 'spaghetti'},
#  {'chocolate', 'green tea'},
#  {'cake',
#   'chocolate',
#   'eggs',
#   'grated cheese',
#   'mashed potato',
#   'mineral water',
#   'pepper',
#   'tomato juice'},
#  {'chocolate'},
#  {'olive oil', 'pancakes', 'spaghetti', 'strong cheese'},
#  {'cookies', 'mineral water', 'red wine', 'rice', 'soup'},
#  {'red wine', 'shrimp', 'spaghetti'},
#  {'green tea'},
#  {'chicken', 'french fries', 'frozen smoothie', 'mineral water'},
#  {'muffins'},
#  {'cake', 'chocolate'},
#  {'avocado',
#   'fresh tuna',
#   'meatballs',
#   'mineral water',
#   'olive oil',
#   'soup',
#   'tomatoes'},
#  {'french fries', 'turkey'},
#  {'burgers',
#   'champagne',
#   'eggs',
#   'fresh bread',
#   'ground beef',
#   'herb & pepper',
#   'light cream',
#   'pancakes',
#   'rice',
#   'turkey'},
#  {'escalope'},
#  {'chocolate', 'escalope', 'fresh bread'},
#  {'chocolate',
#   'french fries',
#   'french wine',
#   'ham',
#   'spaghetti',
#   'vegetables mix'},
#  {'avocado', 'light mayo'},
#  {'butter', 'chocolate', 'spaghetti', 'yams'},
#  {'eggs', 'energy bar', 'french fries'},
#  {'barbecue sauce', 'eggplant', 'fresh tuna'},
#  {'energy drink'},
#  {'french fries', 'green tea', 'hot dogs', 'whole wheat rice'},
#  {'chicken', 'green tea', 'mineral water'},
#  {'cake', 'eggs', 'mushroom cream sauce'},
#  {'escalope'},
#  {'antioxydant juice', 'escalope'},
#  {'french fries', 'shrimp', 'spaghetti'},
#  {'grated cheese', 'salmon', 'spaghetti', 'tomato juice'},
#  {'green tea', 'spaghetti'},
#  {'champagne', 'protein bar'},
#  {'avocado', 'chocolate', 'mineral water'},
#  {'champagne', 'green tea', 'tomatoes'},
#  {'chicken', 'escalope', 'french fries'},
#  {'eggs',
#   'frozen smoothie',
#   'frozen vegetables',
#   'green tea',
#   'light mayo',
#   'tomatoes'},
#  {'champagne',
#   'chicken',
#   'chocolate',
#   'cider',
#   'escalope',
#   'french fries',
#   'frozen smoothie',
#   'green grapes',
#   'ground beef',
#   'honey'},
#  {'champagne', 'french fries'},
#  {'mineral water', 'soup'},
#  {'babies food', 'chocolate', 'frozen vegetables', 'milk', 'spaghetti'},
#  {'honey', 'whole wheat rice'},
#  {'chicken', 'tomato juice', 'whole wheat rice'},
#  {'pancakes'},
#  {'candy bars', 'green tea', 'protein bar', 'tomato juice'},
#  {'french fries'},
#  {'mineral water'},
#  {'escalope'},
#  {'bacon',
#   'grated cheese',
#   'herb & pepper',
#   'mineral water',
#   'nonfat milk',
#   'spinach',
#   'whole wheat pasta',
#   'yams'},
#  {'milk', 'spaghetti'},
#  {'chocolate', 'milk', 'white wine'},
#  {'sandwich'},
#  {'chocolate', 'light mayo'},
#  {'chicken',
#   'frozen smoothie',
#   'meatballs',
#   'shrimp',
#   'spaghetti',
#   'tomato juice',
#   'whole wheat pasta'},
#  {'eggs', 'ground beef', 'mineral water', 'red wine', 'spaghetti'},
#  {'melons', 'yams'},
#  {'cooking oil', 'spaghetti'},
#  {'french fries'},
#  {'chocolate',
#   'cooking oil',
#   'frozen smoothie',
#   'hot dogs',
#   'milk',
#   'mineral water',
#   'spinach'},
#  {'milk', 'tomato sauce'},
#  {'cider', 'eggs', 'french fries', 'shrimp'},
#  {'champagne'},
#  {'salad'},
#  {'french fries'},
#  {'energy bar',
#   'frozen vegetables',
#   'green tea',
#   'honey',
#   'mineral water',
#   'rice'},
#  {'french fries', 'salad'},
#  {'brownies', 'chocolate', 'french fries', 'honey'},
#  {'gluten free bar', 'green tea', 'strawberries'},
#  {'extra dark chocolate',
#   'frozen vegetables',
#   'gluten free bar',
#   'green tea',
#   'ground beef',
#   'honey',
#   'mineral water',
#   'mushroom cream sauce',
#   'salmon'},
#  {'grated cheese', 'meatballs', 'mineral water', 'tomatoes'},
#  {'chocolate', 'shrimp', 'water spray'},
#  {'turkey'},
#  {'eggs', 'turkey'},
#  {'butter',
#   'eggs',
#   'french wine',
#   'fresh bread',
#   'frozen vegetables',
#   'green tea',
#   'pancakes',
#   'soup',
#   'tomato juice',
#   'tomatoes',
#   'turkey'},
#  {'spaghetti'},
#  {'frozen smoothie', 'low fat yogurt', 'milk'},
#  {'burgers',
#   'cereals',
#   'chocolate',
#   'french fries',
#   'milk',
#   'mineral water',
#   'whole wheat rice'},
#  {'mineral water'},
#  {'cake', 'chocolate', 'mineral water', 'soup', 'tomatoes'},
#  {'mineral water'},
#  {'ground beef', 'spaghetti'},
#  {'frozen smoothie', 'pepper'},
#  {'yogurt cake'},
#  {'pancakes', 'red wine'},
#  {'candy bars'},
#  {'eggs', 'french fries', 'low fat yogurt'},
#  {'cookies'},
#  {'cookies'},
#  {'cauliflower',
#   'escalope',
#   'french fries',
#   'soup',
#   'spaghetti',
#   'spinach',
#   'toothpaste',
#   'vegetables mix'},
#  {'cookies'},
#  {'corn', 'eggs', 'olive oil', 'soda', 'soup'},
#  {'chocolate', 'frozen smoothie', 'low fat yogurt'},
#  {'chocolate',
#   'french fries',
#   'milk',
#   'mineral water',
#   'pancakes',
#   'spaghetti'},
#  {'mineral water'},
#  {'almonds',
#   'frozen vegetables',
#   'herb & pepper',
#   'milk',
#   'mineral water',
#   'olive oil',
#   'soup',
#   'tomato sauce'},
#  {'burgers', 'eggs'},
#  {'french fries'},
#  {'cottage cheese', 'frozen smoothie'},
#  {'chocolate', 'light mayo', 'mineral water', 'tomatoes'},
#  {'escalope',
#   'fresh bread',
#   'low fat yogurt',
#   'salmon',
#   'shallot',
#   'strawberries'},
#  {'energy bar'},
#  {'blueberries',
#   'cooking oil',
#   'ground beef',
#   'oil',
#   'pancakes',
#   'red wine',
#   'spaghetti',
#   'tomato juice'},
#  {'champagne',
#   'frozen smoothie',
#   'ground beef',
#   'milk',
#   'mineral water',
#   'spaghetti'},
#  {'cookies'},
#  {'escalope', 'salmon'},
#  {'cookies'},
#  {'low fat yogurt'},
#  {'eggs'},
#  {'butter', 'hot dogs', 'red wine'},
#  {'mashed potato', 'mineral water', 'soup', 'tomatoes'},
#  {'cookies'},
#  {'champagne', 'ground beef', 'pancakes', 'parmesan cheese', 'salmon'},
#  {'chocolate', 'eggs', 'ground beef', 'olive oil', 'yams'},
#  {'cookies', 'eggs', 'hot dogs', 'salmon', 'shrimp'},
#  {'magazines', 'mint'},
#  {'cooking oil',
#   'eggs',
#   'escalope',
#   'extra dark chocolate',
#   'mineral water',
#   'turkey'},
#  {'mineral water', 'mushroom cream sauce'},
#  {'french wine',
#   'frozen vegetables',
#   'grated cheese',
#   'milk',
#   'mineral water',
#   'soup'},
#  {'cake', 'chocolate'},
#  {'burgers', 'salt', 'white wine'},
#  {'energy drink'},
#  {'cake', 'energy drink', 'olive oil'},
#  {'ground beef', 'whole wheat rice'},
#  {'eggs', 'french fries'},
#  {'escalope', 'mushroom cream sauce', 'spaghetti'},
#  {'cake',
#   'french fries',
#   'fromage blanc',
#   'mineral water',
#   'whole wheat rice'},
#  {'burgers',
#   'cake',
#   'eggs',
#   'frozen vegetables',
#   'ground beef',
#   'light mayo',
#   'milk',
#   'mineral water',
#   'turkey'},
#  {'cottage cheese', 'green tea'},
#  {'champagne', 'eggs', 'fresh tuna'},
#  {'cookies'},
#  {'cookies'},
#  {'cookies'},
#  {'eggplant', 'mineral water', 'tomatoes'},
#  {'chicken',
#   'chocolate',
#   'french fries',
#   'grated cheese',
#   'honey',
#   'mineral water',
#   'soup',
#   'spaghetti',
#   'tomatoes'},
#  {'protein bar'},
#  {'barbecue sauce',
#   'herb & pepper',
#   'mineral water',
#   'protein bar',
#   'red wine',
#   'shrimp'},
#  {'burgers',
#   'eggs',
#   'escalope',
#   'french fries',
#   'ham',
#   'low fat yogurt',
#   'milk',
#   'mineral water',
#   'pancakes',
#   'spaghetti'},
#  {'french fries'},
#  {'chocolate',
#   'eggs',
#   'escalope',
#   'frozen vegetables',
#   'melons',
#   'milk',
#   'soup',
#   'whole wheat rice'},
#  {'spaghetti'},
#  {'cooking oil',
#   'eggs',
#   'energy drink',
#   'herb & pepper',
#   'low fat yogurt',
#   'oil',
#   'protein bar',
#   'shrimp',
#   'soup'},
#  {'carrots',
#   'grated cheese',
#   'ground beef',
#   'ham',
#   'herb & pepper',
#   'mineral water',
#   'shrimp',
#   'spaghetti'},
#  {'chocolate',
#   'ground beef',
#   'ham',
#   'low fat yogurt',
#   'mineral water',
#   'red wine',
#   'yams'},
#  {'chocolate',
#   'cottage cheese',
#   'french fries',
#   'low fat yogurt',
#   'mushroom cream sauce'},
#  {'eggs'},
#  {'cake', 'cookies'},
#  {'cake', 'chocolate bread', 'grated cheese', 'mineral water'},
#  {'almonds', 'cake', 'champagne', 'low fat yogurt', 'tomatoes'},
#  {'butter',
#   'chocolate',
#   'eggs',
#   'frozen vegetables',
#   'herb & pepper',
#   'milk',
#   'salmon',
#   'shrimp'},
#  {'cauliflower',
#   'chicken',
#   'green tea',
#   'herb & pepper',
#   'shrimp',
#   'whole wheat pasta',
#   'whole wheat rice'},
#  {'corn', 'eggs'},
#  {'champagne',
#   'chocolate',
#   'frozen vegetables',
#   'green beans',
#   'mineral water',
#   'olive oil',
#   'salmon',
#   'shrimp',
#   'soup',
#   'tomato sauce'},
#  {'eggs',
#   'green grapes',
#   'green tea',
#   'gums',
#   'ham',
#   'herb & pepper',
#   'light cream',
#   'mineral water',
#   'mint',
#   'oil',
#   'tomato sauce'},
#  {'cake', 'chocolate', 'energy bar'},
#  {'eggs', 'herb & pepper', 'shrimp', 'spaghetti'},
#  {'cooking oil', 'fresh tuna', 'honey', 'mineral water'},
#  {'chili',
#   'eggplant',
#   'escalope',
#   'green tea',
#   'ketchup',
#   'low fat yogurt',
#   'mineral water',
#   'oil',
#   'pet food',
#   'red wine',
#   'tomato juice'},
#  {'blueberries',
#   'cake',
#   'eggs',
#   'frozen smoothie',
#   'herb & pepper',
#   'mineral water',
#   'pancakes',
#   'shrimp',
#   'tea'},
#  {'ground beef', 'mineral water', 'protein bar'},
#  {'carrots',
#   'frozen smoothie',
#   'frozen vegetables',
#   'light mayo',
#   'magazines',
#   'mashed potato',
#   'parmesan cheese',
#   'pasta',
#   'salmon',
#   'shallot',
#   'shrimp',
#   'spaghetti'},
#  {'chocolate', 'milk'},
#  {'cottage cheese',
#   'eggplant',
#   'frozen vegetables',
#   'ground beef',
#   'olive oil',
#   'spaghetti',
#   'whole wheat rice'},
#  {'ground beef', 'low fat yogurt', 'turkey'},
#  {'cake',
#   'green tea',
#   'herb & pepper',
#   'hot dogs',
#   'mineral water',
#   'spaghetti',
#   'whole wheat rice'},
#  {'green tea'},
#  {'cookies'},
#  {'cookies', 'eggs'},
#  {'brownies',
#   'champagne',
#   'chocolate',
#   'eggs',
#   'french fries',
#   'ham',
#   'light mayo',
#   'pancakes',
#   'spaghetti'},
#  {'chocolate', 'eggs', 'milk', 'red wine', 'spaghetti'},
#  {'burgers',
#   'french fries',
#   'green tea',
#   'pancakes',
#   'strawberries',
#   'turkey'},
#  {'escalope'},
#  {'cake', 'eggs', 'frozen vegetables', 'pancakes'},
#  {'french fries'},
#  {'cookies', 'ground beef', 'honey', 'pepper', 'spaghetti', 'turkey'},
#  {'chili',
#   'chocolate',
#   'cookies',
#   'french fries',
#   'fresh bread',
#   'magazines',
#   'olive oil',
#   'red wine',
#   'salt',
#   'tomato sauce'},
#  {'french fries', 'green tea'},
#  {'mineral water'},
#  {'cooking oil'},
#  {'frozen vegetables', 'spaghetti'},
#  {'ham', 'spaghetti'},
#  {'chicken', 'chocolate', 'cookies'},
#  {'low fat yogurt'},
#  {'cake', 'eggs', 'low fat yogurt'},
#  {'bramble',
#   'cottage cheese',
#   'frozen smoothie',
#   'milk',
#   'mineral water',
#   'shrimp',
#   'soup',
#   'spaghetti'},
#  {'eggs', 'mineral water', 'protein bar'},
#  {'butter', 'eggs', 'green tea', 'meatballs', 'salad', 'shrimp', 'turkey'},
#  {'chicken',
#   'chocolate',
#   'french fries',
#   'fresh tuna',
#   'olive oil',
#   'spaghetti'},
#  {'escalope', 'hot dogs', 'shrimp', 'turkey'},
#  {'burgers', 'green tea', 'milk', 'pancakes', 'pepper', 'soup'},
#  {'pancakes'},
#  {'eggs', 'french fries', 'mineral water', 'pancakes'},
#  {'eggs', 'escalope', 'low fat yogurt'},
#  {'french wine', 'gluten free bar', 'mineral water'},
#  {'burgers', 'eggs', 'french fries', 'ground beef', 'spaghetti'},
#  {'energy bar', 'meatballs', 'milk', 'soup'},
#  {'chocolate'},
#  {'herb & pepper'},
#  {'bramble', 'eggs', 'mineral water', 'red wine', 'turkey'},
#  {'burgers',
#   'cake',
#   'chicken',
#   'frozen vegetables',
#   'green tea',
#   'ham',
#   'mint',
#   'tomatoes',
#   'toothpaste'},
#  {'energy bar', 'grated cheese', 'mineral water', 'olive oil'},
#  {'cake', 'green tea', 'milk'},
#  {'almonds',
#   'cereals',
#   'cooking oil',
#   'green tea',
#   'mineral water',
#   'protein bar',
#   'white wine'},
#  {'burger sauce',
#   'cake',
#   'chicken',
#   'eggs',
#   'french fries',
#   'fresh bread',
#   'fresh tuna',
#   'frozen smoothie',
#   'milk',
#   'mineral water',
#   'turkey'},
#  {'herb & pepper',
#   'low fat yogurt',
#   'mineral water',
#   'whole wheat rice',
#   'yogurt cake'},
#  {'chicken', 'eggs', 'meatballs', 'spaghetti', 'tomatoes'},
#  {'burgers', 'eggs', 'green tea', 'mineral water', 'pancakes'},
#  {'cake', 'green tea'},
#  {'chocolate', 'herb & pepper', 'yogurt cake'},
#  {'almonds',
#   'green grapes',
#   'ground beef',
#   'mineral water',
#   'nonfat milk',
#   'pancakes',
#   'salmon',
#   'spaghetti'},
#  {'eggs', 'mineral water', 'vegetables mix'},
#  {'protein bar'},
#  {'eggplant', 'eggs'},
#  {'mayonnaise'},
#  {'asparagus', 'bug spray', 'milk', 'oatmeal', 'sandwich'},
#  {'almonds', 'eggs', 'french fries', 'frozen vegetables', 'soup'},
#  {'frozen vegetables'},
#  {'butter', 'shampoo', 'soup'},
#  {'eggs', 'herb & pepper', 'pepper', 'whole wheat pasta'},
#  {'chocolate',
#   'cooking oil',
#   'fresh bread',
#   'low fat yogurt',
#   'mineral water',
#   'rice',
#   'whole wheat rice'},
#  {'butter', 'chocolate', 'cookies', 'french fries', 'grated cheese'},
#  {'asparagus',
#   'chutney',
#   'cooking oil',
#   'milk',
#   'soup',
#   'spaghetti',
#   'tomato juice'},
#  {'champagne',
#   'cookies',
#   'cottage cheese',
#   'eggs',
#   'french fries',
#   'frozen smoothie',
#   'green tea'},
#  {'blueberries', 'eggs', 'mineral water', 'tomatoes', 'turkey'},
#  {'green tea', 'low fat yogurt', 'milk', 'tomato juice'},
#  {'almonds', 'cereals', 'green tea', 'mineral water', 'soup'},
#  {'chocolate', 'light mayo'},
#  {'chocolate', 'herb & pepper', 'turkey'},
#  {'eggs', 'french fries', 'green tea'},
#  {'cake', 'chocolate', 'mineral water', 'tomato juice'},
#  {'eggs'},
#  {'champagne',
#   'chocolate',
#   'mineral water',
#   'mushroom cream sauce',
#   'pepper',
#   'spaghetti',
#   'whole wheat rice'},
#  {'chocolate', 'frozen vegetables', 'mineral water', 'pepper', 'white wine'},
#  {'burgers',
#   'green tea',
#   'milk',
#   'oil',
#   'spaghetti',
#   'tomato juice',
#   'turkey',
#   'whole wheat rice'},
#  {'burgers',
#   'french fries',
#   'french wine',
#   'light mayo',
#   'low fat yogurt',
#   'mineral water',
#   'soup',
#   'spaghetti'},
#  {'butter', 'frozen smoothie', 'green grapes', 'low fat yogurt'},
#  {'eggs', 'low fat yogurt'},
#  {'cookies'},
#  {'energy drink', 'milk'},
#  {'energy drink', 'olive oil'},
#  {'cookies', 'eggs'},
#  {'eggs'},
#  {'eggs', 'energy bar'},
#  {'eggs'},
#  {'eggs', 'green tea'},
#  {'escalope'},
#  {'almonds', 'chocolate', 'eggs', 'milk', 'oil', 'shrimp', 'soup'},
#  {'chocolate', 'french fries'},
#  {'cake'},
#  {'cake', 'eggs', 'green tea', 'pancakes', 'toothpaste'},
#  {'cooking oil', 'eggs', 'ground beef', 'herb & pepper', 'tomatoes'},
#  {'chocolate', 'cider', 'eggs', 'low fat yogurt'},
#  {'cider', 'eggs', 'french fries', 'frozen vegetables'},
#  {'cookies', 'toothpaste', 'yams'},
#  {'champagne', 'escalope', 'fresh bread', 'hot dogs', 'milk', 'mineral water'},
#  {'chocolate',
#   'eggs',
#   'ham',
#   'herb & pepper',
#   'mineral water',
#   'pancakes',
#   'spaghetti'},
#  {'escalope',
#   'mineral water',
#   'pepper',
#   'protein bar',
#   'shallot',
#   'white wine'},
#  {'butter', 'meatballs', 'parmesan cheese', 'spaghetti', 'turkey'},
#  {'eggs', 'escalope', 'herb & pepper'},
#  {'herb & pepper'},
#  {'burgers', 'escalope', 'shallot'},
#  {'chocolate', 'pepper', 'tomato juice', 'tomato sauce'},
#  {'cookies'},
#  {'burgers',
#   'escalope',
#   'ground beef',
#   'melons',
#   'mineral water',
#   'spaghetti'},
#  {'frozen vegetables', 'milk', 'mineral water', 'olive oil', 'soup'},
#  {'asparagus', 'eggs', 'french fries', 'low fat yogurt', 'turkey', 'zucchini'},
#  {'burgers', 'frozen vegetables', 'gums'},
#  {'frozen vegetables', 'ground beef', 'herb & pepper', 'milk'},
#  {'cake', 'frozen vegetables', 'light cream', 'mashed potato'},
#  {'milk'},
#  {'barbecue sauce', 'eggs', 'turkey'},
#  {'escalope'},
#  {'french fries', 'parmesan cheese'},
#  {'eggs', 'energy bar'},
#  {'escalope', 'mint', 'soup'},
#  {'chicken', 'muffins', 'zucchini'},
#  {'burgers', 'cookies', 'eggs', 'french fries', 'green tea'},
#  {'spaghetti'},
#  {'avocado', 'chocolate', 'energy bar'},
#  {'cookies'},
#  {'green tea'},
#  {'mineral water', 'olive oil', 'spaghetti', 'whole wheat pasta'},
#  {'eggs',
#   'escalope',
#   'frozen vegetables',
#   'grated cheese',
#   'gums',
#   'low fat yogurt'},
#  {'chocolate',
#   'escalope',
#   'grated cheese',
#   'herb & pepper',
#   'mineral water',
#   'pancakes',
#   'tomato juice'},
#  {'chocolate', 'flax seed', 'frozen smoothie', 'salmon', 'spaghetti', 'yams'},
#  {'burger sauce', 'oil'},
#  {'eggs', 'energy drink', 'french fries'},
#  {'mineral water'},
#  {'grated cheese', 'ground beef', 'mineral water', 'olive oil'},
#  {'eggs', 'low fat yogurt'},
#  {'parmesan cheese', 'pet food', 'soda', 'spaghetti', 'white wine'},
#  {'chicken',
#   'eggs',
#   'extra dark chocolate',
#   'fresh bread',
#   'melons',
#   'olive oil',
#   'shrimp',
#   'turkey'},
#  {'escalope',
#   'french fries',
#   'ground beef',
#   'milk',
#   'muffins',
#   'pickles',
#   'salmon',
#   'strong cheese',
#   'yams'},
#  {'light cream', 'pepper', 'spaghetti'},
#  {'eggs', 'frozen vegetables', 'mineral water'},
#  {'chicken', 'gluten free bar', 'pancakes', 'spaghetti', 'tea'},
#  {'fresh tuna',
#   'herb & pepper',
#   'mineral water',
#   'mint',
#   'spaghetti',
#   'turkey'},
#  {'cooking oil', 'escalope', 'mineral water', 'spaghetti'},
#  {'soup'},
#  {'burgers', 'herb & pepper', 'spaghetti'},
#  {'cookies', 'shallot', 'strawberries'},
#  {'chocolate',
#   'fresh tuna',
#   'milk',
#   'mineral water',
#   'pepper',
#   'salmon',
#   'shrimp',
#   'soup',
#   'whole wheat pasta'},
#  {'avocado',
#   'butter',
#   'chocolate',
#   'cooking oil',
#   'cottage cheese',
#   'milk',
#   'mineral water',
#   'yams'},
#  {'eggs', 'energy drink', 'french fries', 'ham'},
#  {'avocado', 'mineral water'},
#  {'cookies'},
#  {'butter', 'chocolate', 'cottage cheese', 'eggs', 'green tea', 'mayonnaise'},
#  {'eggs', 'low fat yogurt', 'mushroom cream sauce'},
#  {'antioxydant juice', 'chocolate'},
#  {'french fries', 'green tea', 'ground beef', 'spaghetti'},
#  {'cake'},
#  {'chocolate',
#   'cooking oil',
#   'eggs',
#   'mineral water',
#   'pancakes',
#   'red wine',
#   'turkey',
#   'whole wheat rice',
#   'zucchini'},
#  {'bacon', 'chocolate', 'mineral water', 'olive oil', 'parmesan cheese'},
#  {'green grapes', 'gums'},
#  {'chocolate',
#   'cooking oil',
#   'eggs',
#   'french fries',
#   'frozen vegetables',
#   'milk',
#   'parmesan cheese',
#   'shrimp'},
#  {'eggs', 'ground beef', 'milk', 'mineral water'},
#  {'escalope'},
#  {'cookies', 'turkey'},
#  {'chocolate', 'green tea', 'ground beef', 'mineral water'},
#  {'butter',
#   'chocolate',
#   'french fries',
#   'low fat yogurt',
#   'olive oil',
#   'spaghetti',
#   'tomato juice',
#   'whole wheat pasta'},
#  {'red wine'},
#  {'cooking oil',
#   'cottage cheese',
#   'eggs',
#   'frozen smoothie',
#   'frozen vegetables',
#   'gums',
#   'low fat yogurt',
#   'mineral water'},
#  {'brownies', 'energy bar', 'grated cheese', 'turkey', 'vegetables mix'},
#  {'burgers', 'cooking oil', 'energy drink', 'nonfat milk', 'turkey'},
#  {'french fries', 'low fat yogurt'},
#  {'muffins'},
#  {'cake',
#   'green tea',
#   'herb & pepper',
#   'mineral water',
#   'salmon',
#   'whole wheat rice'},
#  {'cake', 'candy bars', 'chocolate', 'low fat yogurt', 'mineral water'},
#  {'chicken',
#   'chocolate',
#   'grated cheese',
#   'light cream',
#   'milk',
#   'mineral water',
#   'olive oil',
#   'soup'},
#  {'mineral water', 'strawberries'},
#  {'escalope'},
#  {'butter',
#   'cooking oil',
#   'grated cheese',
#   'parmesan cheese',
#   'whole wheat rice'},
#  {'ground beef', 'mint'},
#  {'cookies'},
#  {'avocado', 'chicken', 'ground beef', 'milk', 'rice'},
#  {'eggs', 'frozen vegetables', 'low fat yogurt', 'soup'},
#  {'black tea',
#   'chocolate',
#   'french wine',
#   'green tea',
#   'ground beef',
#   'herb & pepper',
#   'mineral water',
#   'pancakes',
#   'rice',
#   'spaghetti',
#   'toothpaste'},
#  {'cake',
#   'cooking oil',
#   'eggs',
#   'low fat yogurt',
#   'mineral water',
#   'oil',
#   'parmesan cheese',
#   'shrimp',
#   'toothpaste'},
#  {'black tea',
#   'cooking oil',
#   'frozen smoothie',
#   'frozen vegetables',
#   'green tea',
#   'ham',
#   'herb & pepper',
#   'mint',
#   'olive oil',
#   'spaghetti',
#   'tomatoes',
#   'vegetables mix'},
#  {'chicken', 'cider', 'eggs'},
#  {'chocolate', 'escalope', 'mineral water', 'mint', 'shrimp', 'tomato sauce'},
#  {'energy drink'},
#  {'cooking oil',
#   'eggs',
#   'energy bar',
#   'fresh bread',
#   'ham',
#   'low fat yogurt',
#   'mineral water',
#   'pancakes',
#   'spaghetti'},
#  {'frozen vegetables', 'shrimp', 'tomatoes'},
#  {'frozen vegetables',
#   'ground beef',
#   'herb & pepper',
#   'mineral water',
#   'salmon',
#   'turkey',
#   'yams'},
#  {'mineral water', 'shrimp'},
#  {'escalope', 'ground beef', 'soup', 'spaghetti', 'turkey', 'yogurt cake'},
#  {'barbecue sauce',
#   'clothes accessories',
#   'cookies',
#   'eggs',
#   'milk',
#   'mineral water',
#   'pepper',
#   'rice',
#   'shrimp',
#   'soup'},
#  {'burgers', 'pancakes'},
#  {'low fat yogurt'},
#  {'milk', 'mineral water'},
#  {'milk'},
#  {'chocolate'},
#  {'mineral water', 'olive oil', 'pancakes', 'whole wheat pasta'},
#  {'cake', 'eggs', 'mineral water', 'yams'},
#  {'french fries', 'turkey'},
#  {'chicken',
#   'chocolate',
#   'french fries',
#   'green tea',
#   'light cream',
#   'mineral water',
#   'olive oil',
#   'sandwich',
#   'shrimp',
#   'spaghetti',
#   'white wine',
#   'yams'},
#  {'cookies', 'fresh bread', 'green tea', 'milk', 'mineral water', 'salmon'},
#  {'olive oil', 'spaghetti'},
#  {'herb & pepper', 'spaghetti'},
#  {'chicken',
#   'low fat yogurt',
#   'mineral water',
#   'mint green tea',
#   'pancakes',
#   'salmon',
#   'soup',
#   'spaghetti'},
#  {'almonds',
#   'chocolate',
#   'french wine',
#   'fresh bread',
#   'frozen vegetables',
#   'ground beef',
#   'milk',
#   'mineral water',
#   'olive oil',
#   'whole wheat pasta',
#   'yogurt cake'},
#  {'green tea'},
#  {'burgers',
#   'chocolate',
#   'eggs',
#   'grated cheese',
#   'gums',
#   'low fat yogurt',
#   'nonfat milk',
#   'spaghetti',
#   'tomato juice'},
#  {'brownies',
#   'chicken',
#   'energy bar',
#   'ground beef',
#   'ham',
#   'olive oil',
#   'white wine'},
#  {'cooking oil',
#   'frozen smoothie',
#   'green tea',
#   'mineral water',
#   'olive oil',
#   'whole wheat pasta'},
#  {'champagne', 'vegetables mix'},
#  {'olive oil'},
#  {'escalope', 'green tea', 'ground beef', 'herb & pepper', 'pancakes'},
#  {'chocolate',
#   'eggs',
#   'escalope',
#   'french wine',
#   'frozen vegetables',
#   'green tea',
#   'ground beef',
#   'herb & pepper',
#   'hot dogs',
#   'milk',
#   'mineral water',
#   'spaghetti',
#   'tomato sauce',
#   'whole wheat rice'},
#  {'carrots', 'yams'},
#  {'chicken'},
#  {'almonds',
#   'avocado',
#   'burgers',
#   'eggs',
#   'french fries',
#   'ground beef',
#   'herb & pepper',
#   'milk',
#   'mineral water',
#   'muffins',
#   'turkey',
#   'yams'},
#  {'antioxydant juice', 'mint green tea', 'salmon', 'whole wheat pasta'},
#  {'chocolate', 'french fries', 'fresh bread', 'strawberries'},
#  {'asparagus',
#   'burgers',
#   'chocolate',
#   'energy bar',
#   'ground beef',
#   'shrimp',
#   'soup',
#   'whole wheat pasta'},
#  {'butter',
#   'french fries',
#   'frozen smoothie',
#   'low fat yogurt',
#   'mineral water',
#   'pancakes',
#   'white wine'},
#  {'eggs', 'muffins'},
#  {'eggs', 'frozen vegetables', 'shrimp', 'turkey'},
#  {'burgers', 'eggs', 'yogurt cake'},
#  {'almonds',
#   'burgers',
#   'cake',
#   'chicken',
#   'extra dark chocolate',
#   'fresh tuna',
#   'frozen vegetables',
#   'mineral water',
#   'olive oil',
#   'shrimp',
#   'whole wheat pasta',
#   'yams'},
#  {'chicken', 'ground beef', 'herb & pepper', 'mineral water'},
#  {'frozen smoothie'},
#  {'chicken', 'tomato juice'},
#  {'olive oil', 'whole wheat pasta'},
#  {'energy bar', 'green tea', 'milk'},
#  {'grated cheese', 'herb & pepper'},
#  {'escalope', 'green tea'},
#  {'almonds', 'green tea', 'meatballs', 'milk', 'soup'},
#  {'cookies', 'herb & pepper', 'pet food'},
#  {'energy bar',
#   'french fries',
#   'grated cheese',
#   'light cream',
#   'low fat yogurt',
#   'oil',
#   'olive oil',
#   'pancakes',
#   'whole wheat pasta'},
#  {'honey'},
#  {'eggs',
#   'fromage blanc',
#   'frozen smoothie',
#   'honey',
#   'mineral water',
#   'parmesan cheese'},
#  {'bramble', 'zucchini'},
#  {'chocolate',
#   'eggs',
#   'green tea',
#   'ground beef',
#   'milk',
#   'pepper',
#   'white wine'},
#  {'butter',
#   'chocolate',
#   'cookies',
#   'french fries',
#   'low fat yogurt',
#   'red wine'},
#  {'bug spray', 'chocolate', 'spaghetti'},
#  {'cookies'},
#  {'eggs',
#   'fresh bread',
#   'mineral water',
#   'spaghetti',
#   'vegetables mix',
#   'whole wheat rice'},
#  {'burger sauce',
#   'chocolate',
#   'escalope',
#   'grated cheese',
#   'low fat yogurt',
#   'mineral water',
#   'mushroom cream sauce',
#   'salmon',
#   'whole wheat rice'},
#  {'champagne', 'spaghetti'},
#  {'frozen vegetables', 'mineral water'},
#  {'body spray', 'low fat yogurt', 'mineral water'},
#  {'cake', 'herb & pepper', 'red wine', 'tomato juice', 'whole wheat pasta'},
#  {'burgers', 'eggs', 'french fries', 'hot dogs', 'parmesan cheese'},
#  {'eggs', 'mineral water', 'pancakes'},
#  {'eggs', 'french fries'},
#  {'frozen vegetables', 'shrimp', 'spaghetti', 'tomatoes'},
#  {'almonds',
#   'chocolate',
#   'french fries',
#   'green tea',
#   'mineral water',
#   'pancakes'},
#  {'cake', 'escalope', 'french fries'},
#  {'black tea',
#   'chutney',
#   'cider',
#   'french wine',
#   'frozen vegetables',
#   'milk',
#   'mineral water',
#   'salmon',
#   'spaghetti'},
#  {'almonds', 'cake', 'low fat yogurt'},
#  {'french fries'},
#  {'hot dogs'},
#  {'champagne',
#   'chicken',
#   'chocolate',
#   'green tea',
#   'light cream',
#   'low fat yogurt',
#   'mineral water',
#   'soup'},
#  {'ground beef', 'olive oil'},
#  {'cookies', 'french fries', 'green tea'},
#  {'blueberries',
#   'champagne',
#   'chocolate',
#   'cookies',
#   'cooking oil',
#   'salt',
#   'soup'},
#  {'chocolate', 'escalope', 'french fries', 'fresh bread', 'frozen smoothie'},
#  {'mint', 'yams'},
#  {'chocolate',
#   'frozen vegetables',
#   'ground beef',
#   'magazines',
#   'muffins',
#   'salmon'},
#  {'cake',
#   'chocolate',
#   'fresh tuna',
#   'herb & pepper',
#   'honey',
#   'milk',
#   'olive oil',
#   'pancakes',
#   'parmesan cheese'},
#  {'butter',
#   'cookies',
#   'cottage cheese',
#   'escalope',
#   'french fries',
#   'grated cheese',
#   'shrimp',
#   'whole wheat rice'},
#  {'body spray', 'champagne', 'eggs', 'energy bar', 'french fries'},
#  {'burgers', 'eggs', 'french fries'},
#  {'burgers',
#   'chocolate',
#   'eggs',
#   'french fries',
#   'fresh bread',
#   'milk',
#   'mineral water',
#   'shrimp'},
#  {'chicken',
#   'chocolate',
#   'green tea',
#   'ground beef',
#   'milk',
#   'mineral water',
#   'nonfat milk'},
#  {'chicken', 'mineral water'},
#  {'cake', 'eggs', 'ground beef', 'milk', 'spaghetti', 'turkey'},
#  {'french fries', 'green tea'},
#  {'escalope', 'french fries'},
#  {'sparkling water', 'turkey'},
#  {'carrots',
#   'low fat yogurt',
#   'mineral water',
#   'olive oil',
#   'protein bar',
#   'whole wheat pasta'},
#  {'cookies'},
#  {'french fries', 'grated cheese', 'green beans', 'honey', 'turkey'},
#  {'barbecue sauce',
#   'chicken',
#   'chocolate',
#   'light cream',
#   'mineral water',
#   'oil',
#   'red wine',
#   'rice',
#   'soup',
#   'turkey'},
#  {'eggs', 'turkey'},
#  {'low fat yogurt'},
#  {'low fat yogurt', 'nonfat milk'},
#  {'frozen vegetables', 'low fat yogurt'},
#  {'eggs',
#   'herb & pepper',
#   'low fat yogurt',
#   'milk',
#   'mineral water',
#   'mint',
#   'parmesan cheese',
#   'whole wheat pasta'},
#  {'mint', 'yogurt cake'},
#  {'salt', 'sandwich'},
#  {'fresh bread', 'green tea', 'shrimp'},
#  {'escalope', 'pepper', 'tomato sauce'},
#  {'cake', 'mineral water', 'protein bar', 'toothpaste'},
#  {'candy bars'},
#  {'red wine'},
#  {'honey', 'mineral water', 'spaghetti', 'strawberries'},
#  {'eggs', 'green tea', 'mineral water'},
#  {'french fries',
#   'french wine',
#   'fresh bread',
#   'frozen vegetables',
#   'grated cheese',
#   'green tea',
#   'parmesan cheese'},
#  {'avocado',
#   'cake',
#   'chocolate',
#   'frozen vegetables',
#   'milk',
#   'mineral water',
#   'muffins',
#   'olive oil',
#   'parmesan cheese',
#   'spaghetti',
#   'whole wheat pasta'},
#  {'chocolate',
#   'grated cheese',
#   'honey',
#   'mint',
#   'olive oil',
#   'shrimp',
#   'spaghetti',
#   'strawberries'},
#  {'spaghetti', 'strawberries'},
#  {'burgers', 'chocolate', 'mushroom cream sauce'},
#  {'extra dark chocolate', 'mineral water', 'olive oil'},
#  {'eggs', 'green tea'},
#  {'tomato juice'},
#  {'low fat yogurt', 'muffins'},
#  {'champagne',
#   'light cream',
#   'low fat yogurt',
#   'olive oil',
#   'pancakes',
#   'soup'},
#  {'low fat yogurt', 'mineral water', 'vegetables mix'},
#  {'avocado',
#   'chocolate',
#   'eggs',
#   'green tea',
#   'honey',
#   'mineral water',
#   'pancakes',
#   'pepper'},
#  {'almonds', 'burgers', 'frozen smoothie', 'honey', 'pickles'},
#  {'bug spray', 'clothes accessories', 'cottage cheese'},
#  {'french fries',
#   'frozen smoothie',
#   'frozen vegetables',
#   'green beans',
#   'ground beef',
#   'honey',
#   'mashed potato',
#   'pancakes',
#   'spaghetti',
#   'whole wheat rice'},
#  {'milk', 'mineral water', 'spaghetti'},
#  {'pancakes'},
#  {'muffins'},
#  {'cereals', 'frozen vegetables', 'oil'},
#  {'almonds',
#   'cake',
#   'frozen smoothie',
#   'milk',
#   'mineral water',
#   'shrimp',
#   'strong cheese',
#   'turkey'},
#  {'chocolate', 'eggplant', 'hand protein bar', 'rice', 'zucchini'},
#  {'hot dogs', 'meatballs', 'nonfat milk', 'spaghetti'},
#  {'cake', 'cookies', 'frozen vegetables', 'pancakes'},
#  {'bug spray', 'butter', 'french fries', 'green tea', 'yogurt cake'},
#  {'herb & pepper'},
#  {'chicken', 'cider', 'green beans', 'milk', 'soup'},
#  {'avocado',
#   'escalope',
#   'frozen smoothie',
#   'hot dogs',
#   'milk',
#   'mineral water',
#   'salmon',
#   'shrimp',
#   'spaghetti'},
#  {'champagne', 'escalope', 'milk', 'whole wheat rice'},
#  {'escalope', 'mushroom cream sauce', 'pasta'},
#  {'parmesan cheese'},
#  {'french fries', 'grated cheese', 'spaghetti'},
#  {'burgers',
#   'cake',
#   'chicken',
#   'milk',
#   'mineral water',
#   'olive oil',
#   'pancakes',
#   'salmon',
#   'shrimp',
#   'spaghetti',
#   'whole wheat pasta'},
#  {'bacon',
#   'butter',
#   'chocolate',
#   'frozen vegetables',
#   'grated cheese',
#   'ground beef',
#   'milk',
#   'spaghetti',
#   'turkey',
#   'whole wheat rice'},
#  {'chocolate',
#   'eggs',
#   'escalope',
#   'fromage blanc',
#   'green tea',
#   'pepper',
#   'turkey'},
#  {'avocado', 'green tea', 'ground beef', 'milk', 'pancakes', 'tomatoes'},
#  {'green tea', 'mineral water', 'protein bar', 'turkey'},
#  {'low fat yogurt', 'mineral water'},
#  {'candy bars', 'pancakes', 'tomato juice'},
#  {'avocado',
#   'bacon',
#   'brownies',
#   'french fries',
#   'green tea',
#   'oil',
#   'pancakes',
#   'yams',
#   'zucchini'},
#  {'burger sauce',
#   'cake',
#   'chicken',
#   'milk',
#   'mineral water',
#   'oil',
#   'olive oil',
#   'shrimp',
#   'soup',
#   'spaghetti'},
#  {'chicken', 'cooking oil', 'tea'},
#  {'asparagus',
#   'body spray',
#   'burgers',
#   'green tea',
#   'mayonnaise',
#   'melons',
#   'mint',
#   'pancakes',
#   'protein bar',
#   'soup',
#   'vegetables mix'},
#  {'pepper', 'shrimp'},
#  {'blueberries', 'olive oil', 'spaghetti'},
#  {'muffins'},
#  {'eggs', 'grated cheese', 'herb & pepper', 'low fat yogurt', 'muffins'},
#  {'cooking oil',
#   'frozen vegetables',
#   'gluten free bar',
#   'grated cheese',
#   'gums',
#   'light cream',
#   'milk',
#   'spaghetti'},
#  {'french fries', 'pancakes', 'pepper', 'tomato juice'},
#  {'extra dark chocolate',
#   'frozen vegetables',
#   'green tea',
#   'ground beef',
#   'melons',
#   'milk',
#   'mint',
#   'parmesan cheese',
#   'tomato sauce',
#   'tomatoes'},
#  {'chicken', 'chocolate', 'cookies', 'green tea', 'olive oil'},
#  {'chocolate',
#   'eggs',
#   'french wine',
#   'frozen smoothie',
#   'ground beef',
#   'pancakes',
#   'sandwich',
#   'spaghetti',
#   'tomato juice',
#   'whole wheat pasta'},
#  {'cottage cheese', 'eggs'},
#  {'cottage cheese', 'muffins'},
#  {'frozen smoothie', 'green tea', 'white wine'},
#  {'champagne', 'chocolate', 'mineral water', 'rice'},
#  {'mineral water'},
#  {'meatballs', 'milk', 'shrimp', 'whole wheat pasta'},
#  {'almonds',
#   'black tea',
#   'cream',
#   'eggs',
#   'french wine',
#   'ground beef',
#   'herb & pepper',
#   'pancakes',
#   'parmesan cheese',
#   'pepper',
#   'spaghetti'},
#  {'grated cheese',
#   'ground beef',
#   'mineral water',
#   'mint',
#   'parmesan cheese',
#   'shrimp'},
#  {'mineral water', 'rice'},
#  {'pancakes'},
#  {'honey', 'mineral water'},
#  {'burgers', 'ground beef', 'pancakes', 'salt'},
#  {'brownies', 'french fries', 'parmesan cheese', 'soda'},
#  {'whole wheat rice'},
#  {'chicken',
#   'cooking oil',
#   'ground beef',
#   'hot dogs',
#   'mint',
#   'oil',
#   'rice',
#   'spaghetti'},
#  {'butter', 'chocolate'},
#  {'pepper'},
#  {'champagne', 'chocolate', 'green tea', 'herb & pepper', 'yogurt cake'},
#  {'eggs', 'escalope', 'grated cheese', 'mineral water'},
#  {'cookies', 'green tea', 'light mayo', 'yogurt cake'},
#  {'cooking oil', 'milk'},
#  {'cereals',
#   'chicken',
#   'cooking oil',
#   'extra dark chocolate',
#   'french fries',
#   'fresh bread',
#   'frozen smoothie',
#   'light cream',
#   'low fat yogurt',
#   'milk',
#   'olive oil',
#   'pancakes',
#   'tomato juice'},
#  {'avocado',
#   'energy drink',
#   'green tea',
#   'low fat yogurt',
#   'milk',
#   'soup',
#   'tomatoes',
#   'yogurt cake'},
#  {'chocolate', 'ground beef', 'ham', 'mineral water', 'oil'},
#  {'champagne', 'escalope', 'green tea'},
#  {'chocolate'},
#  {'escalope', 'pasta'},
#  {'antioxydant juice',
#   'burgers',
#   'frozen smoothie',
#   'mineral water',
#   'olive oil',
#   'rice'},
#  {'green tea'},
#  {'energy drink',
#   'grated cheese',
#   'milk',
#   'pancakes',
#   'spaghetti',
#   'tomato sauce',
#   'white wine'},
#  {'spaghetti', 'strawberries', 'strong cheese', 'turkey'},
#  {'muffins'},
#  {'cider', 'cookies', 'cooking oil', 'ground beef', 'spaghetti'},
#  {'burgers',
#   'fromage blanc',
#   'frozen vegetables',
#   'honey',
#   'hot dogs',
#   'low fat yogurt',
#   'pancakes',
#   'parmesan cheese',
#   'spaghetti',
#   'vegetables mix'},
#  {'ground beef'},
#  {'green beans'},
#  {'champagne',
#   'escalope',
#   'frozen vegetables',
#   'honey',
#   'mineral water',
#   'whole wheat rice'},
#  {'black tea',
#   'butter',
#   'eggs',
#   'frozen smoothie',
#   'green tea',
#   'light mayo',
#   'low fat yogurt',
#   'milk',
#   'parmesan cheese',
#   'shampoo'},
#  {'cake', 'mineral water'},
#  {'cookies',
#   'cooking oil',
#   'frozen smoothie',
#   'green tea',
#   'milk',
#   'mineral water',
#   'pancakes',
#   'turkey',
#   'whole wheat rice'},
#  {'avocado', 'chocolate', 'french fries'},
#  {'green tea'},
#  {'bug spray', 'chocolate', 'eggs'},
#  {'body spray', 'french fries', 'grated cheese', 'muffins'},
#  {'blueberries', 'eggs', 'escalope', 'mineral water', 'soda'},
#  {'whole wheat rice'},
#  {'cookies', 'mushroom cream sauce', 'nonfat milk'},
#  {'champagne', 'french fries'},
#  {'mineral water', 'salmon'},
#  {'olive oil'},
#  {'brownies',
#   'butter',
#   'cake',
#   'ground beef',
#   'honey',
#   'milk',
#   'mint green tea',
#   'salt',
#   'soup',
#   'tomatoes',
#   'turkey'},
#  {'chocolate',
#   'low fat yogurt',
#   'mineral water',
#   'napkins',
#   'parmesan cheese',
#   'spaghetti'},
#  {'almonds',
#   'burgers',
#   'butter',
#   'cake',
#   'chocolate',
#   'eggs',
#   'energy bar',
#   'fromage blanc',
#   'milk',
#   'olive oil',
#   'pancakes',
#   'parmesan cheese',
#   'soup'},
#  {'energy drink', 'green tea', 'honey', 'pasta', 'shrimp'},
#  {'champagne',
#   'chocolate',
#   'french wine',
#   'fresh tuna',
#   'frozen smoothie',
#   'milk',
#   'muffins',
#   'pancakes'},
#  {'strawberries'},
#  {'herb & pepper'},
#  {'cake',
#   'cereals',
#   'champagne',
#   'eggs',
#   'french fries',
#   'fromage blanc',
#   'frozen vegetables',
#   'ground beef',
#   'herb & pepper',
#   'honey',
#   'parmesan cheese',
#   'rice',
#   'tomatoes'},
#  {'cereals',
#   'cottage cheese',
#   'escalope',
#   'milk',
#   'mineral water',
#   'spaghetti',
#   'strong cheese'},
#  {'burgers',
#   'cake',
#   'cottage cheese',
#   'eggs',
#   'energy drink',
#   'fresh tuna',
#   'gluten free bar',
#   'pancakes',
#   'spaghetti',
#   'turkey'},
#  {'eggplant'},
#  {'almonds',
#   'burgers',
#   'carrots',
#   'extra dark chocolate',
#   'honey',
#   'mashed potato',
#   'mineral water',
#   'spaghetti'},
#  {'chocolate',
#   'cottage cheese',
#   'french fries',
#   'frozen smoothie',
#   'light mayo',
#   'strawberries'},
#  {'strong cheese'},
#  {'chocolate', 'french fries'},
#  {'chocolate', 'french fries', 'strawberries'},
#  {'avocado',
#   'cake',
#   'chicken',
#   'chocolate bread',
#   'cooking oil',
#   'frozen vegetables',
#   'light cream',
#   'mashed potato',
#   'turkey'},
#  {'energy bar', 'olive oil', 'shallot'},
#  {'shrimp', 'turkey'},
#  {'champagne', 'chocolate', 'spaghetti', 'yogurt cake'},
#  {'avocado',
#   'butter',
#   'chocolate',
#   'green tea',
#   'mineral water',
#   'shrimp',
#   'zucchini'},
#  {'brownies', 'green tea', 'muffins'},
#  {'yogurt cake'},
#  {'bacon',
#   'butter',
#   'chocolate',
#   'cooking oil',
#   'french fries',
#   'hot dogs',
#   'melons',
#   'milk',
#   'mint',
#   'protein bar',
#   'salmon',
#   'tomato sauce',
#   'turkey'},
#  {'grated cheese'},
#  {'brownies', 'burger sauce', 'butter', 'pancakes'},
#  {'butter',
#   'cookies',
#   'french fries',
#   'green tea',
#   'low fat yogurt',
#   'pancakes',
#   'shallot',
#   'whole wheat rice'},
#  {'butter', 'chocolate', 'cooking oil', 'escalope', 'shrimp'},
#  {'burgers',
#   'cereals',
#   'chocolate',
#   'cooking oil',
#   'frozen vegetables',
#   'honey',
#   'milk',
#   'pepper',
#   'red wine',
#   'spaghetti',
#   'whole wheat rice'},
#  {'cake',
#   'chili',
#   'chocolate',
#   'eggs',
#   'ground beef',
#   'pancakes',
#   'pet food',
#   'spaghetti',
#   'turkey'},
#  {'butter', 'chicken', 'green tea', 'mayonnaise', 'milk', 'salt', 'shrimp'},
#  {'chocolate',
#   'french fries',
#   'fresh tuna',
#   'fromage blanc',
#   'frozen smoothie',
#   'green tea',
#   'gums',
#   'honey',
#   'mineral water',
#   'sparkling water',
#   'strawberries'},
#  {'chocolate', 'cookies'},
#  {'light mayo', 'sparkling water'},
#  {'chicken',
#   'escalope',
#   'french fries',
#   'frozen vegetables',
#   'spaghetti',
#   'tomatoes'},
#  {'barbecue sauce',
#   'burgers',
#   'butter',
#   'cake',
#   'eggs',
#   'green grapes',
#   'green tea',
#   'pancakes',
#   'turkey',
#   'vegetables mix'},
#  {'burger sauce', 'eggs', 'red wine', 'shrimp', 'yams', 'yogurt cake'},
#  {'french fries', 'light mayo'},
#  {'burgers', 'champagne', 'chocolate', 'eggs', 'ground beef', 'zucchini'},
#  {'mushroom cream sauce'},
#  {'butter', 'mint green tea'},
#  {'whole wheat rice'},
#  {'gums'},
#  {'champagne', 'french fries', 'green tea', 'mineral water'},
#  {'cereals', 'green tea', 'salt'},
#  {'brownies',
#   'chocolate',
#   'cookies',
#   'escalope',
#   'french fries',
#   'melons',
#   'pancakes',
#   'shrimp',
#   'spaghetti'},
#  {'chicken',
#   'chocolate',
#   'cooking oil',
#   'ham',
#   'hot dogs',
#   'spaghetti',
#   'yams'},
#  {'eggs'},
#  {'bug spray', 'frozen smoothie', 'ground beef', 'hot dogs', 'olive oil'},
#  {'escalope',
#   'frozen vegetables',
#   'mineral water',
#   'olive oil',
#   'soup',
#   'spaghetti'},
#  {'chicken', 'escalope', 'french fries', 'oil', 'whole wheat rice'},
#  {'green tea'},
#  {'champagne', 'escalope', 'parmesan cheese', 'whole wheat rice'},
#  {'chicken',
#   'fresh tuna',
#   'fromage blanc',
#   'frozen vegetables',
#   'honey',
#   'light mayo'},
#  {'ground beef'},
#  {'champagne', 'cookies', 'fresh bread', 'green tea', 'muffins'},
#  {'chocolate', 'escalope', 'fresh bread', 'frozen vegetables', 'spaghetti'},
#  {'french fries', 'frozen smoothie', 'pickles', 'spaghetti'},
#  {'avocado'},
#  {'sandwich'},
#  {'milk', 'oil', 'shampoo', 'spaghetti'},
#  {'champagne'},
#  {'spaghetti'},
#  {'champagne'},
#  {'avocado', 'butter', 'cookies', 'french fries', 'milk'},
#  {'cauliflower',
#   'chicken',
#   'eggs',
#   'frozen smoothie',
#   'frozen vegetables',
#   'low fat yogurt',
#   'turkey'},
#  {'almonds',
#   'body spray',
#   'burgers',
#   'chicken',
#   'chocolate',
#   'energy bar',
#   'french fries',
#   'milk',
#   'shrimp',
#   'tomatoes'},
#  {'burgers',
#   'cake',
#   'cooking oil',
#   'escalope',
#   'french fries',
#   'milk',
#   'zucchini'},
#  {'cake',
#   'chocolate',
#   'frozen smoothie',
#   'milk',
#   'olive oil',
#   'protein bar',
#   'spaghetti',
#   'tomatoes',
#   'whole wheat rice'},
#  {'eggs',
#   'fresh tuna',
#   'fromage blanc',
#   'green tea',
#   'honey',
#   'pancakes',
#   'pepper',
#   'red wine',
#   'salmon',
#   'spaghetti'},
#  {'low fat yogurt', 'milk'},
#  {'brownies', 'chocolate', 'parmesan cheese', 'shrimp', 'soup'},
#  {'chicken', 'spaghetti'},
#  {'grated cheese', 'green tea', 'nonfat milk', 'vegetables mix'},
#  {'cider',
#   'fresh tuna',
#   'honey',
#   'muffins',
#   'oil',
#   'parmesan cheese',
#   'spinach'},
#  {'cake'},
#  {'candy bars', 'chocolate', 'mushroom cream sauce', 'shrimp'},
#  {'candy bars'},
#  {'avocado', 'honey'},
#  {'cottage cheese', 'frozen vegetables', 'shrimp', 'tomatoes'},
#  {'french fries'},
#  {'strawberries'},
#  {'almonds', 'escalope', 'french fries', 'ground beef'},
#  {'grated cheese', 'spaghetti'},
#  {'butter', 'frozen smoothie', 'mineral water', 'turkey'},
#  {'french fries', 'frozen vegetables', 'green tea', 'light mayo', 'spaghetti'},
#  {'burgers',
#   'chocolate',
#   'cookies',
#   'eggplant',
#   'green tea',
#   'ham',
#   'shallot',
#   'spaghetti',
#   'whole wheat rice'},
#  {'avocado',
#   'blueberries',
#   'chocolate',
#   'cookies',
#   'french fries',
#   'frozen smoothie',
#   'frozen vegetables',
#   'grated cheese',
#   'green tea',
#   'hot dogs',
#   'light cream',
#   'milk',
#   'rice',
#   'spaghetti'},
#  {'bacon', 'burgers', 'green tea', 'shrimp', 'tomatoes', 'whole wheat rice'},
#  {'pancakes', 'parmesan cheese'},
#  {'cake', 'green tea', 'hot dogs', 'parmesan cheese'},
#  {'babies food', 'chocolate', 'fromage blanc', 'ketchup', 'milk', 'spaghetti'},
#  {'mint'},
#  {'chocolate', 'mint'},
#  {'butter', 'french fries', 'fresh bread', 'salt'},
#  {'chocolate', 'french fries', 'light mayo', 'strawberries', 'yogurt cake'},
#  {'cookies', 'eggplant', 'eggs'},
#  {'yogurt cake'},
#  {'chicken',
#   'escalope',
#   'frozen smoothie',
#   'herb & pepper',
#   'honey',
#   'meatballs',
#   'milk',
#   'olive oil',
#   'pancakes',
#   'spaghetti'},
#  {'chocolate', 'frozen vegetables', 'rice'},
#  {'chocolate',
#   'eggs',
#   'ground beef',
#   'herb & pepper',
#   'light cream',
#   'milk',
#   'spaghetti'},
#  {'champagne', 'eggs'},
#  {'blueberries', 'escalope', 'ground beef', 'olive oil', 'whole wheat pasta'},
#  {'burgers',
#   'carrots',
#   'eggs',
#   'hand protein bar',
#   'mineral water',
#   'oil',
#   'red wine',
#   'tomato juice'},
#  {'chocolate',
#   'grated cheese',
#   'herb & pepper',
#   'mineral water',
#   'olive oil',
#   'soup'},
#  {'burgers',
#   'cake',
#   'chicken',
#   'eggs',
#   'fromage blanc',
#   'frozen smoothie',
#   'mineral water',
#   'salmon',
#   'shrimp',
#   'strawberries'},
#  {'green tea'},
#  {'cookies'},
#  {'cookies', 'french fries'},
#  {'butter', 'eggs', 'milk'},
#  {'eggs', 'low fat yogurt', 'mushroom cream sauce'},
#  {'eggs', 'green tea'},
#  {'mineral water', 'whole wheat rice'},
#  {'cake',
#   'frozen vegetables',
#   'mineral water',
#   'parmesan cheese',
#   'shrimp',
#   'whole wheat rice'},
#  {'pancakes', 'whole wheat rice'},
#  {'butter',
#   'cauliflower',
#   'cooking oil',
#   'frozen smoothie',
#   'frozen vegetables',
#   'oil',
#   'olive oil',
#   'salmon',
#   'spaghetti'},
#  {'green tea'},
#  {'eggs', 'escalope', 'fresh tuna', 'strawberries'},
#  {'carrots', 'chocolate', 'milk', 'soup', 'spaghetti'},
#  {'burgers', 'meatballs', 'mineral water', 'olive oil', 'soup'},
#  {'cookies',
#   'cooking oil',
#   'french fries',
#   'grated cheese',
#   'low fat yogurt',
#   'mineral water'},
#  {'french fries', 'milk', 'olive oil', 'shrimp'},
#  {'cake', 'frozen vegetables', 'mineral water', 'pancakes', 'tomato juice'},
#  {'chicken', 'milk', 'spaghetti'},
#  {'chicken',
#   'cottage cheese',
#   'french fries',
#   'grated cheese',
#   'mineral water',
#   'pancakes'},
#  {'eggs', 'ground beef', 'milk', 'mineral water', 'mint'},
#  {'body spray', 'green tea', 'shrimp'},
#  {'frozen smoothie'},
#  {'cereals', 'frozen vegetables', 'herb & pepper', 'mineral water', 'muffins'},
#  {'brownies',
#   'cake',
#   'cider',
#   'eggs',
#   'french fries',
#   'green tea',
#   'honey',
#   'milk',
#   'spaghetti',
#   'tomato juice',
#   'tomatoes',
#   'turkey'},
#  ...]

# %%
#Storing unique items in a list
unique_list = []
for trans in new_record:
    for item in trans:
        # check if exists in unique_list or not
        if item not in unique_list:
          unique_list.append(item)

# %%
unique_list
# Out:
# ['shrimp',
#  'almonds',
#  'avocado',
#  'vegetables mix',
#  'green grapes',
#  'whole weat flour',
#  'yams',
#  'cottage cheese',
#  'energy drink',
#  'tomato juice',
#  'low fat yogurt',
#  'green tea',
#  'honey',
#  'salad',
#  'mineral water',
#  'salmon',
#  'antioxydant juice',
#  'frozen smoothie',
#  'spinach',
#  'olive oil',
#  'burgers',
#  'meatballs',
#  'eggs',
#  'chutney',
#  'turkey',
#  'milk',
#  'energy bar',
#  'whole wheat rice',
#  'whole wheat pasta',
#  'french fries',
#  'soup',
#  'light cream',
#  'shallot',
#  'frozen vegetables',
#  'spaghetti',
#  'pet food',
#  'cookies',
#  'cooking oil',
#  'champagne',
#  'chocolate',
#  'chicken',
#  'oil',
#  'fresh tuna',
#  'tomatoes',
#  'black tea',
#  'extra dark chocolate',
#  'protein bar',
#  'red wine',
#  'pasta',
#  'pepper',
#  'shampoo',
#  'rice',
#  'sparkling water',
#  'ham',
#  'body spray',
#  'pancakes',
#  'grated cheese',
#  'white wine',
#  'toothpaste',
#  'parmesan cheese',
#  'fresh bread',
#  'ground beef',
#  'escalope',
#  'herb & pepper',
#  'tomato sauce',
#  'magazines',
#  'strawberries',
#  'strong cheese',
#  'pickles',
#  'cake',
#  'hot dogs',
#  'brownies',
#  'cereals',
#  'clothes accessories',
#  'bug spray',
#  'muffins',
#  'light mayo',
#  'gums',
#  'soda',
#  'cider',
#  'corn',
#  'yogurt cake',
#  'mint',
#  'butter',
#  'asparagus',
#  'french wine',
#  'salt',
#  'tea',
#  'barbecue sauce',
#  'mayonnaise',
#  'zucchini',
#  'carrots',
#  'mushroom cream sauce',
#  'candy bars',
#  'chili',
#  'mashed potato',
#  'nonfat milk',
#  'water spray',
#  'chocolate bread',
#  'mint green tea',
#  'eggplant',
#  'blueberries',
#  'bacon',
#  'fromage blanc',
#  'gluten free bar',
#  'dessert wine',
#  'flax seed',
#  'hand protein bar',
#  'sandwich',
#  'babies food',
#  'melons',
#  'cauliflower',
#  'green beans',
#  'ketchup',
#  'bramble',
#  'burger sauce',
#  'oatmeal',
#  'cream',
#  'napkins']

# %%
#Converting list of unique string item to list of set item
unique_set = []

for i in unique_list:
  temp = set()
  temp.add(i)
  unique_set.append(temp)

# %%
unique_set
# Out:
# [{'shrimp'},
#  {'almonds'},
#  {'avocado'},
#  {'vegetables mix'},
#  {'green grapes'},
#  {'whole weat flour'},
#  {'yams'},
#  {'cottage cheese'},
#  {'energy drink'},
#  {'tomato juice'},
#  {'low fat yogurt'},
#  {'green tea'},
#  {'honey'},
#  {'salad'},
#  {'mineral water'},
#  {'salmon'},
#  {'antioxydant juice'},
#  {'frozen smoothie'},
#  {'spinach'},
#  {'olive oil'},
#  {'burgers'},
#  {'meatballs'},
#  {'eggs'},
#  {'chutney'},
#  {'turkey'},
#  {'milk'},
#  {'energy bar'},
#  {'whole wheat rice'},
#  {'whole wheat pasta'},
#  {'french fries'},
#  {'soup'},
#  {'light cream'},
#  {'shallot'},
#  {'frozen vegetables'},
#  {'spaghetti'},
#  {'pet food'},
#  {'cookies'},
#  {'cooking oil'},
#  {'champagne'},
#  {'chocolate'},
#  {'chicken'},
#  {'oil'},
#  {'fresh tuna'},
#  {'tomatoes'},
#  {'black tea'},
#  {'extra dark chocolate'},
#  {'protein bar'},
#  {'red wine'},
#  {'pasta'},
#  {'pepper'},
#  {'shampoo'},
#  {'rice'},
#  {'sparkling water'},
#  {'ham'},
#  {'body spray'},
#  {'pancakes'},
#  {'grated cheese'},
#  {'white wine'},
#  {'toothpaste'},
#  {'parmesan cheese'},
#  {'fresh bread'},
#  {'ground beef'},
#  {'escalope'},
#  {'herb & pepper'},
#  {'tomato sauce'},
#  {'magazines'},
#  {'strawberries'},
#  {'strong cheese'},
#  {'pickles'},
#  {'cake'},
#  {'hot dogs'},
#  {'brownies'},
#  {'cereals'},
#  {'clothes accessories'},
#  {'bug spray'},
#  {'muffins'},
#  {'light mayo'},
#  {'gums'},
#  {'soda'},
#  {'cider'},
#  {'corn'},
#  {'yogurt cake'},
#  {'mint'},
#  {'butter'},
#  {'asparagus'},
#  {'french wine'},
#  {'salt'},
#  {'tea'},
#  {'barbecue sauce'},
#  {'mayonnaise'},
#  {'zucchini'},
#  {'carrots'},
#  {'mushroom cream sauce'},
#  {'candy bars'},
#  {'chili'},
#  {'mashed potato'},
#  {'nonfat milk'},
#  {'water spray'},
#  {'chocolate bread'},
#  {'mint green tea'},
#  {'eggplant'},
#  {'blueberries'},
#  {'bacon'},
#  {'fromage blanc'},
#  {'gluten free bar'},
#  {'dessert wine'},
#  {'flax seed'},
#  {'hand protein bar'},
#  {'sandwich'},
#  {'babies food'},
#  {'melons'},
#  {'cauliflower'},
#  {'green beans'},
#  {'ketchup'},
#  {'bramble'},
#  {'burger sauce'},
#  {'oatmeal'},
#  {'cream'},
#  {'napkins'}]

# %%
#Function to calculate support
glb2 = []
glb2_supp = []

glb_support_store = []

def Process_Support(unique_set, min_supp, flag = True):
  #print("Number of unique sets with element :: ",len(unique_set[0]),"are", len(unique_set))
  while(flag):
   
    #Frequency of item set
    count = []

    for item_chq in unique_set:
      item_count = 0
      for trans in k:
        if(item_chq.issubset(trans)):
            item_count+= 1
      count.append(item_count)

    #Calculating support of item set
    support = []

    for z in count:
      supp_val = (z / no_of_trans)
      support.append(supp_val)

    #*************************************************
    supp_store = []
    for i in range(0, len(unique_set)):
      glb2.append(unique_set[i])
      glb2_supp.append(support[i])
    #*************************************************

    #Checking minimum support value    
    new_list = []
    len_min_supp = 0
    for i in range(0, len(support)):
      if(support[i] > min_supp):
        new_list.append(unique_set[i]) 
        len_min_supp+= 1 
        print("Rule: ", unique_set[i] ," -> ", "Support: ", support[i])
        print("--------------------------------------------------------------------------")
         
        if unique_set[i] not in glb_support_store:
          glb_support_store.append(unique_set[i])

    print("LENGTH = ", len_min_supp)
    print("*************************************************************************")

    #Creating new item set Dataset for association using union operator
    new_list2 = []
    for i in range(0,len(new_list)-1):
      for j in range(i+1,len(new_list)):
        temp = new_list[i]|new_list[j]
        if temp not in new_list2:
          new_list2.append(temp)

    if(len_min_supp==0):
      Process_Support(new_list2, min_supp, False)
    else:
      Process_Support(new_list2, min_supp)
    return
  return

# %%
Process_Support(unique_set, min_supp = 0.04)
# Out:
# Rule:  {'shrimp'}  ->  Support:  0.07145713904812692
# --------------------------------------------------------------------------
# Rule:  {'low fat yogurt'}  ->  Support:  0.07652313024930009
# --------------------------------------------------------------------------
# Rule:  {'green tea'}  ->  Support:  0.13211571790427942
# --------------------------------------------------------------------------
# Rule:  {'honey'}  ->  Support:  0.047460338621517134
# --------------------------------------------------------------------------
# Rule:  {'mineral water'}  ->  Support:  0.23836821757099053
# --------------------------------------------------------------------------
# Rule:  {'salmon'}  ->  Support:  0.04252766297826956
# --------------------------------------------------------------------------
# Rule:  {'frozen smoothie'}  ->  Support:  0.06332489001466471
# --------------------------------------------------------------------------
# Rule:  {'olive oil'}  ->  Support:  0.0658578856152513
# --------------------------------------------------------------------------
# Rule:  {'burgers'}  ->  Support:  0.0871883748833489
# --------------------------------------------------------------------------
# Rule:  {'eggs'}  ->  Support:  0.17970937208372217
# --------------------------------------------------------------------------
# Rule:  {'turkey'}  ->  Support:  0.06252499666711105
# --------------------------------------------------------------------------
# Rule:  {'milk'}  ->  Support:  0.12958272230369283
# --------------------------------------------------------------------------
# Rule:  {'whole wheat rice'}  ->  Support:  0.058525529929342755
# --------------------------------------------------------------------------
# Rule:  {'french fries'}  ->  Support:  0.1709105452606319
# --------------------------------------------------------------------------
# Rule:  {'soup'}  ->  Support:  0.05052659645380616
# --------------------------------------------------------------------------
# Rule:  {'frozen vegetables'}  ->  Support:  0.09532062391681109
# --------------------------------------------------------------------------
# Rule:  {'spaghetti'}  ->  Support:  0.17411011865084655
# --------------------------------------------------------------------------
# Rule:  {'cookies'}  ->  Support:  0.08038928142914278
# --------------------------------------------------------------------------
# Rule:  {'cooking oil'}  ->  Support:  0.0510598586855086
# --------------------------------------------------------------------------
# Rule:  {'champagne'}  ->  Support:  0.04679376083188908
# --------------------------------------------------------------------------
# Rule:  {'chocolate'}  ->  Support:  0.1638448206905746
# --------------------------------------------------------------------------
# Rule:  {'chicken'}  ->  Support:  0.05999200106652446
# --------------------------------------------------------------------------
# Rule:  {'tomatoes'}  ->  Support:  0.06839088121583789
# --------------------------------------------------------------------------
# Rule:  {'pancakes'}  ->  Support:  0.09505399280095987
# --------------------------------------------------------------------------
# Rule:  {'grated cheese'}  ->  Support:  0.0523930142647647
# --------------------------------------------------------------------------
# Rule:  {'fresh bread'}  ->  Support:  0.043060925209972005
# --------------------------------------------------------------------------
# Rule:  {'ground beef'}  ->  Support:  0.09825356619117451
# --------------------------------------------------------------------------
# Rule:  {'escalope'}  ->  Support:  0.0793227569657379
# --------------------------------------------------------------------------
# Rule:  {'herb & pepper'}  ->  Support:  0.04946007199040128
# --------------------------------------------------------------------------
# Rule:  {'cake'}  ->  Support:  0.08105585921877083
# --------------------------------------------------------------------------
# LENGTH =  30
# *************************************************************************
# Rule:  {'mineral water', 'eggs'}  ->  Support:  0.05092654312758299
# --------------------------------------------------------------------------
# Rule:  {'mineral water', 'milk'}  ->  Support:  0.04799360085321957
# --------------------------------------------------------------------------
# Rule:  {'mineral water', 'spaghetti'}  ->  Support:  0.05972536995067324
# --------------------------------------------------------------------------
# Rule:  {'mineral water', 'chocolate'}  ->  Support:  0.05265964538061592
# --------------------------------------------------------------------------
# Rule:  {'mineral water', 'ground beef'}  ->  Support:  0.040927876283162246
# --------------------------------------------------------------------------
# LENGTH =  5
# *************************************************************************
# LENGTH =  0
# *************************************************************************

# %%
glb_support_store
# Out:
# [{'shrimp'},
#  {'low fat yogurt'},
#  {'green tea'},
#  {'honey'},
#  {'mineral water'},
#  {'salmon'},
#  {'frozen smoothie'},
#  {'olive oil'},
#  {'burgers'},
#  {'eggs'},
#  {'turkey'},
#  {'milk'},
#  {'whole wheat rice'},
#  {'french fries'},
#  {'soup'},
#  {'frozen vegetables'},
#  {'spaghetti'},
#  {'cookies'},
#  {'cooking oil'},
#  {'champagne'},
#  {'chocolate'},
#  {'chicken'},
#  {'tomatoes'},
#  {'pancakes'},
#  {'grated cheese'},
#  {'fresh bread'},
#  {'ground beef'},
#  {'escalope'},
#  {'herb & pepper'},
#  {'cake'},
#  {'eggs', 'mineral water'},
#  {'milk', 'mineral water'},
#  {'mineral water', 'spaghetti'},
#  {'chocolate', 'mineral water'},
#  {'ground beef', 'mineral water'}]

# %%
#print(len(glb2))
#print(len(glb2_supp))

# %%
#For printing all items set which are ever stored in Candidate Item Table
#for i in range(0, len(glb2)):
#  print(glb2[i],"---->","support : ",glb2_supp[i])

# %%
association_store = []

for asso in glb_support_store:
  if(len(asso)>1):
    association_store.append(asso)

# %%
#assoction_store stores unique sets for confidence check
association_store
# Out:
# [{'eggs', 'mineral water'},
#  {'milk', 'mineral water'},
#  {'mineral water', 'spaghetti'},
#  {'chocolate', 'mineral water'},
#  {'ground beef', 'mineral water'}]

# %%
#Confidence to be calculated further

# %%
import itertools
from itertools import combinations, chain

def findsubsets(s, n):
    return list(map(set, itertools.combinations(s, n)))

# %%
def common_data(set1, set2):
    result = False
  
    # traverse in the 1st list
    for x in set1:
  
        # traverse in the 2nd list
        for y in set2:
    
            # if one common
            if x == y:
                result = True
                return result 
                  
    return result

def find_support(set1, set2, set3):
  
  for i in range(0, len(glb2)):
    if(set1==glb2[i]):
      x = glb2_supp[i]
      break

  for j in range(0, len(glb2)):
    if(set2==glb2[j]):
      y = glb2_supp[j]
      break

  for k in range(0, len(glb2)):
    if(set3==glb2[k]):
      z = glb2_supp[k]
      break
  return (x, y, z)

# %%
#assoction_store stores unique sets for confidence check
association_store
# Out:
# [{'eggs', 'mineral water'},
#  {'milk', 'mineral water'},
#  {'mineral water', 'spaghetti'},
#  {'chocolate', 'mineral water'},
#  {'ground beef', 'mineral water'}]

# %%
#For calulating Associations Rules whose confidence is less then min_conf

def process_confidence(list_ass_rule, min_conf):
  l1 = []

  for asso_set in list_ass_rule:
    ln = len(asso_set)

    all_subset = []
    for i in range(1, ln):
      p = findsubsets(asso_set, i)
      #print(p)
      for item in p:
        all_subset.append(item)

    
    for j in range(0, len(all_subset)-1):
      for k in range(j+1, len(all_subset)):
        if( (all_subset[j].issubset(all_subset[k])==False ) and (len(all_subset[j])+len(all_subset[k])==ln) and ( common_data(all_subset[j], all_subset[k])==False) ):
          sup1, sup2, sup3 = find_support( asso_set, all_subset[j], all_subset[k] )
          
          conf1 = sup1 / sup2
          if( conf1>= min_conf):
            print(all_subset[j],"--->",all_subset[k]," ::  confidence = ",conf1)
      
          conf2 = sup1 / sup3
          if( conf2>=min_conf):
            print(all_subset[k],"--->",all_subset[j]," ::  confidence = ",conf2)

    #print("-----------------------------------------------------------------------------------------------------------")

# %%
process_confidence(association_store, min_conf = 0.3)
# Out:
# {'milk'} ---> {'mineral water'}  ::  confidence =  0.3703703703703704
# {'spaghetti'} ---> {'mineral water'}  ::  confidence =  0.3430321592649311
# {'chocolate'} ---> {'mineral water'}  ::  confidence =  0.3213995117982099
# {'ground beef'} ---> {'mineral water'}  ::  confidence =  0.41655359565807326

# %%
#----------------------------------------CROSS CHECK OUR RESULT USING APRORI LIBRARY-----------------------------------------------
# !pip install apyori
# Out:
# Requirement already satisfied: apyori in /usr/local/lib/python3.7/dist-packages (1.1.2)

# %%
from apyori import apriori

# %%
ass_rules = apriori(new_record,  min_support = .04, confidence = 0.2)
ass_rslts = list(ass_rules)

# %%
print(len(ass_rslts))
# Out:
# 35

# %%
ass_rslts
# Out:
# [RelationRecord(items=frozenset({'burgers'}), support=0.0871883748833489, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'burgers'}), confidence=0.0871883748833489, lift=1.0)]),
#  RelationRecord(items=frozenset({'cake'}), support=0.08105585921877083, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'cake'}), confidence=0.08105585921877083, lift=1.0)]),
#  RelationRecord(items=frozenset({'champagne'}), support=0.04679376083188908, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'champagne'}), confidence=0.04679376083188908, lift=1.0)]),
#  RelationRecord(items=frozenset({'chicken'}), support=0.05999200106652446, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'chicken'}), confidence=0.05999200106652446, lift=1.0)]),
#  RelationRecord(items=frozenset({'chocolate'}), support=0.1638448206905746, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'chocolate'}), confidence=0.1638448206905746, lift=1.0)]),
#  RelationRecord(items=frozenset({'cookies'}), support=0.08038928142914278, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'cookies'}), confidence=0.08038928142914278, lift=1.0)]),
#  RelationRecord(items=frozenset({'cooking oil'}), support=0.0510598586855086, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'cooking oil'}), confidence=0.0510598586855086, lift=1.0)]),
#  RelationRecord(items=frozenset({'eggs'}), support=0.17970937208372217, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'eggs'}), confidence=0.17970937208372217, lift=1.0)]),
#  RelationRecord(items=frozenset({'escalope'}), support=0.0793227569657379, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'escalope'}), confidence=0.0793227569657379, lift=1.0)]),
#  RelationRecord(items=frozenset({'french fries'}), support=0.1709105452606319, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'french fries'}), confidence=0.1709105452606319, lift=1.0)]),
#  RelationRecord(items=frozenset({'fresh bread'}), support=0.043060925209972005, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'fresh bread'}), confidence=0.043060925209972005, lift=1.0)]),
#  RelationRecord(items=frozenset({'frozen smoothie'}), support=0.06332489001466471, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'frozen smoothie'}), confidence=0.06332489001466471, lift=1.0)]),
#  RelationRecord(items=frozenset({'frozen vegetables'}), support=0.09532062391681109, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'frozen vegetables'}), confidence=0.09532062391681109, lift=1.0)]),
#  RelationRecord(items=frozenset({'grated cheese'}), support=0.0523930142647647, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'grated cheese'}), confidence=0.0523930142647647, lift=1.0)]),
#  RelationRecord(items=frozenset({'green tea'}), support=0.13211571790427942, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'green tea'}), confidence=0.13211571790427942, lift=1.0)]),
#  RelationRecord(items=frozenset({'ground beef'}), support=0.09825356619117451, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'ground beef'}), confidence=0.09825356619117451, lift=1.0)]),
#  RelationRecord(items=frozenset({'herb & pepper'}), support=0.04946007199040128, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'herb & pepper'}), confidence=0.04946007199040128, lift=1.0)]),
#  RelationRecord(items=frozenset({'honey'}), support=0.047460338621517134, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'honey'}), confidence=0.047460338621517134, lift=1.0)]),
#  RelationRecord(items=frozenset({'low fat yogurt'}), support=0.07652313024930009, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'low fat yogurt'}), confidence=0.07652313024930009, lift=1.0)]),
#  RelationRecord(items=frozenset({'milk'}), support=0.12958272230369283, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'milk'}), confidence=0.12958272230369283, lift=1.0)]),
#  RelationRecord(items=frozenset({'mineral water'}), support=0.23836821757099053, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'mineral water'}), confidence=0.23836821757099053, lift=1.0)]),
#  RelationRecord(items=frozenset({'olive oil'}), support=0.0658578856152513, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'olive oil'}), confidence=0.0658578856152513, lift=1.0)]),
#  RelationRecord(items=frozenset({'pancakes'}), support=0.09505399280095987, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'pancakes'}), confidence=0.09505399280095987, lift=1.0)]),
#  RelationRecord(items=frozenset({'salmon'}), support=0.04252766297826956, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'salmon'}), confidence=0.04252766297826956, lift=1.0)]),
#  RelationRecord(items=frozenset({'shrimp'}), support=0.07145713904812692, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'shrimp'}), confidence=0.07145713904812692, lift=1.0)]),
#  RelationRecord(items=frozenset({'soup'}), support=0.05052659645380616, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'soup'}), confidence=0.05052659645380616, lift=1.0)]),
#  RelationRecord(items=frozenset({'spaghetti'}), support=0.17411011865084655, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'spaghetti'}), confidence=0.17411011865084655, lift=1.0)]),
#  RelationRecord(items=frozenset({'tomatoes'}), support=0.06839088121583789, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'tomatoes'}), confidence=0.06839088121583789, lift=1.0)]),
#  RelationRecord(items=frozenset({'turkey'}), support=0.06252499666711105, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'turkey'}), confidence=0.06252499666711105, lift=1.0)]),
#  RelationRecord(items=frozenset({'whole wheat rice'}), support=0.058525529929342755, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'whole wheat rice'}), confidence=0.058525529929342755, lift=1.0)]),
#  RelationRecord(items=frozenset({'mineral water', 'chocolate'}), support=0.05265964538061592, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'mineral water', 'chocolate'}), confidence=0.05265964538061592, lift=1.0), OrderedStatistic(items_base=frozenset({'chocolate'}), items_add=frozenset({'mineral water'}), confidence=0.3213995117982099, lift=1.3483320682317521), OrderedStatistic(items_base=frozenset({'mineral water'}), items_add=frozenset({'chocolate'}), confidence=0.220917225950783, lift=1.348332068231752)]),
#  RelationRecord(items=frozenset({'eggs', 'mineral water'}), support=0.05092654312758299, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'eggs', 'mineral water'}), confidence=0.05092654312758299, lift=1.0), OrderedStatistic(items_base=frozenset({'eggs'}), items_add=frozenset({'mineral water'}), confidence=0.28338278931750743, lift=1.188844688294532), OrderedStatistic(items_base=frozenset({'mineral water'}), items_add=frozenset({'eggs'}), confidence=0.21364653243847875, lift=1.188844688294532)]),
#  RelationRecord(items=frozenset({'mineral water', 'ground beef'}), support=0.040927876283162246, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'mineral water', 'ground beef'}), confidence=0.040927876283162246, lift=1.0), OrderedStatistic(items_base=frozenset({'ground beef'}), items_add=frozenset({'mineral water'}), confidence=0.41655359565807326, lift=1.7475215442008991), OrderedStatistic(items_base=frozenset({'mineral water'}), items_add=frozenset({'ground beef'}), confidence=0.17170022371364654, lift=1.7475215442008993)]),
#  RelationRecord(items=frozenset({'mineral water', 'milk'}), support=0.04799360085321957, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'mineral water', 'milk'}), confidence=0.04799360085321957, lift=1.0), OrderedStatistic(items_base=frozenset({'milk'}), items_add=frozenset({'mineral water'}), confidence=0.3703703703703704, lift=1.5537741320739085), OrderedStatistic(items_base=frozenset({'mineral water'}), items_add=frozenset({'milk'}), confidence=0.20134228187919462, lift=1.5537741320739085)]),
#  RelationRecord(items=frozenset({'spaghetti', 'mineral water'}), support=0.05972536995067324, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'spaghetti', 'mineral water'}), confidence=0.05972536995067324, lift=1.0), OrderedStatistic(items_base=frozenset({'mineral water'}), items_add=frozenset({'spaghetti'}), confidence=0.2505592841163311, lift=1.4390851379453289), OrderedStatistic(items_base=frozenset({'spaghetti'}), items_add=frozenset({'mineral water'}), confidence=0.3430321592649311, lift=1.4390851379453289)])]

# %%
for item in ass_rslts:
    # first index of the inner list
    # Contains base item and add item
   # pair = item[0]
    #items = [x for x in pair]
    print("Rule: ", item[0] ," -> ", "Support: ",item[1], "Confidence: ",item[2])
    print("--------------------------------------------------------------------------")
# Out:
# Rule:  frozenset({'burgers'})  ->  Support:  0.0871883748833489 Confidence:  [OrderedStatistic(items_base=frozenset(), items_add=frozenset({'burgers'}), confidence=0.0871883748833489, lift=1.0)]
# --------------------------------------------------------------------------
# Rule:  frozenset({'cake'})  ->  Support:  0.08105585921877083 Confidence:  [OrderedStatistic(items_base=frozenset(), items_add=frozenset({'cake'}), confidence=0.08105585921877083, lift=1.0)]
# --------------------------------------------------------------------------
# Rule:  frozenset({'champagne'})  ->  Support:  0.04679376083188908 Confidence:  [OrderedStatistic(items_base=frozenset(), items_add=frozenset({'champagne'}), confidence=0.04679376083188908, lift=1.0)]
# --------------------------------------------------------------------------
# Rule:  frozenset({'chicken'})  ->  Support:  0.05999200106652446 Confidence:  [OrderedStatistic(items_base=frozenset(), items_add=frozenset({'chicken'}), confidence=0.05999200106652446, lift=1.0)]
# --------------------------------------------------------------------------
# Rule:  frozenset({'chocolate'})  ->  Support:  0.1638448206905746 Confidence:  [OrderedStatistic(items_base=frozenset(), items_add=frozenset({'chocolate'}), confidence=0.1638448206905746, lift=1.0)]
# --------------------------------------------------------------------------
# Rule:  frozenset({'cookies'})  ->  Support:  0.08038928142914278 Confidence:  [OrderedStatistic(items_base=frozenset(), items_add=frozenset({'cookies'}), confidence=0.08038928142914278, lift=1.0)]
# --------------------------------------------------------------------------
# Rule:  frozenset({'cooking oil'})  ->  Support:  0.0510598586855086 Confidence:  [OrderedStatistic(items_base=frozenset(), items_add=frozenset({'cooking oil'}), confidence=0.0510598586855086, lift=1.0)]
# --------------------------------------------------------------------------
# Rule:  frozenset({'eggs'})  ->  Support:  0.17970937208372217 Confidence:  [OrderedStatistic(items_base=frozenset(), items_add=frozenset({'eggs'}), confidence=0.17970937208372217, lift=1.0)]
# --------------------------------------------------------------------------
# Rule:  frozenset({'escalope'})  ->  Support:  0.0793227569657379 Confidence:  [OrderedStatistic(items_base=frozenset(), items_add=frozenset({'escalope'}), confidence=0.0793227569657379, lift=1.0)]
# --------------------------------------------------------------------------
# Rule:  frozenset({'french fries'})  ->  Support:  0.1709105452606319 Confidence:  [OrderedStatistic(items_base=frozenset(), items_add=frozenset({'french fries'}), confidence=0.1709105452606319, lift=1.0)]
# --------------------------------------------------------------------------
# Rule:  frozenset({'fresh bread'})  ->  Support:  0.043060925209972005 Confidence:  [OrderedStatistic(items_base=frozenset(), items_add=frozenset({'fresh bread'}), confidence=0.043060925209972005, lift=1.0)]
# --------------------------------------------------------------------------
# Rule:  frozenset({'frozen smoothie'})  ->  Support:  0.06332489001466471 Confidence:  [OrderedStatistic(items_base=frozenset(), items_add=frozenset({'frozen smoothie'}), confidence=0.06332489001466471, lift=1.0)]
# --------------------------------------------------------------------------
# Rule:  frozenset({'frozen vegetables'})  ->  Support:  0.09532062391681109 Confidence:  [OrderedStatistic(items_base=frozenset(), items_add=frozenset({'frozen vegetables'}), confidence=0.09532062391681109, lift=1.0)]
# --------------------------------------------------------------------------
# Rule:  frozenset({'grated cheese'})  ->  Support:  0.0523930142647647 Confidence:  [OrderedStatistic(items_base=frozenset(), items_add=frozenset({'grated cheese'}), confidence=0.0523930142647647, lift=1.0)]
# --------------------------------------------------------------------------
# Rule:  frozenset({'green tea'})  ->  Support:  0.13211571790427942 Confidence:  [OrderedStatistic(items_base=frozenset(), items_add=frozenset({'green tea'}), confidence=0.13211571790427942, lift=1.0)]
# --------------------------------------------------------------------------
# Rule:  frozenset({'ground beef'})  ->  Support:  0.09825356619117451 Confidence:  [OrderedStatistic(items_base=frozenset(), items_add=frozenset({'ground beef'}), confidence=0.09825356619117451, lift=1.0)]
# --------------------------------------------------------------------------
# Rule:  frozenset({'herb & pepper'})  ->  Support:  0.04946007199040128 Confidence:  [OrderedStatistic(items_base=frozenset(), items_add=frozenset({'herb & pepper'}), confidence=0.04946007199040128, lift=1.0)]
# --------------------------------------------------------------------------
# Rule:  frozenset({'honey'})  ->  Support:  0.047460338621517134 Confidence:  [OrderedStatistic(items_base=frozenset(), items_add=frozenset({'honey'}), confidence=0.047460338621517134, lift=1.0)]
# --------------------------------------------------------------------------
# Rule:  frozenset({'low fat yogurt'})  ->  Support:  0.07652313024930009 Confidence:  [OrderedStatistic(items_base=frozenset(), items_add=frozenset({'low fat yogurt'}), confidence=0.07652313024930009, lift=1.0)]
# --------------------------------------------------------------------------
# Rule:  frozenset({'milk'})  ->  Support:  0.12958272230369283 Confidence:  [OrderedStatistic(items_base=frozenset(), items_add=frozenset({'milk'}), confidence=0.12958272230369283, lift=1.0)]
# --------------------------------------------------------------------------
# Rule:  frozenset({'mineral water'})  ->  Support:  0.23836821757099053 Confidence:  [OrderedStatistic(items_base=frozenset(), items_add=frozenset({'mineral water'}), confidence=0.23836821757099053, lift=1.0)]
# --------------------------------------------------------------------------
# Rule:  frozenset({'olive oil'})  ->  Support:  0.0658578856152513 Confidence:  [OrderedStatistic(items_base=frozenset(), items_add=frozenset({'olive oil'}), confidence=0.0658578856152513, lift=1.0)]
# --------------------------------------------------------------------------
# Rule:  frozenset({'pancakes'})  ->  Support:  0.09505399280095987 Confidence:  [OrderedStatistic(items_base=frozenset(), items_add=frozenset({'pancakes'}), confidence=0.09505399280095987, lift=1.0)]
# --------------------------------------------------------------------------
# Rule:  frozenset({'salmon'})  ->  Support:  0.04252766297826956 Confidence:  [OrderedStatistic(items_base=frozenset(), items_add=frozenset({'salmon'}), confidence=0.04252766297826956, lift=1.0)]
# --------------------------------------------------------------------------
# Rule:  frozenset({'shrimp'})  ->  Support:  0.07145713904812692 Confidence:  [OrderedStatistic(items_base=frozenset(), items_add=frozenset({'shrimp'}), confidence=0.07145713904812692, lift=1.0)]
# --------------------------------------------------------------------------
# Rule:  frozenset({'soup'})  ->  Support:  0.05052659645380616 Confidence:  [OrderedStatistic(items_base=frozenset(), items_add=frozenset({'soup'}), confidence=0.05052659645380616, lift=1.0)]
# --------------------------------------------------------------------------
# Rule:  frozenset({'spaghetti'})  ->  Support:  0.17411011865084655 Confidence:  [OrderedStatistic(items_base=frozenset(), items_add=frozenset({'spaghetti'}), confidence=0.17411011865084655, lift=1.0)]
# --------------------------------------------------------------------------
# Rule:  frozenset({'tomatoes'})  ->  Support:  0.06839088121583789 Confidence:  [OrderedStatistic(items_base=frozenset(), items_add=frozenset({'tomatoes'}), confidence=0.06839088121583789, lift=1.0)]
# --------------------------------------------------------------------------
# Rule:  frozenset({'turkey'})  ->  Support:  0.06252499666711105 Confidence:  [OrderedStatistic(items_base=frozenset(), items_add=frozenset({'turkey'}), confidence=0.06252499666711105, lift=1.0)]
# --------------------------------------------------------------------------
# Rule:  frozenset({'whole wheat rice'})  ->  Support:  0.058525529929342755 Confidence:  [OrderedStatistic(items_base=frozenset(), items_add=frozenset({'whole wheat rice'}), confidence=0.058525529929342755, lift=1.0)]
# --------------------------------------------------------------------------
# Rule:  frozenset({'mineral water', 'chocolate'})  ->  Support:  0.05265964538061592 Confidence:  [OrderedStatistic(items_base=frozenset(), items_add=frozenset({'mineral water', 'chocolate'}), confidence=0.05265964538061592, lift=1.0), OrderedStatistic(items_base=frozenset({'chocolate'}), items_add=frozenset({'mineral water'}), confidence=0.3213995117982099, lift=1.3483320682317521), OrderedStatistic(items_base=frozenset({'mineral water'}), items_add=frozenset({'chocolate'}), confidence=0.220917225950783, lift=1.348332068231752)]
# --------------------------------------------------------------------------
# Rule:  frozenset({'eggs', 'mineral water'})  ->  Support:  0.05092654312758299 Confidence:  [OrderedStatistic(items_base=frozenset(), items_add=frozenset({'eggs', 'mineral water'}), confidence=0.05092654312758299, lift=1.0), OrderedStatistic(items_base=frozenset({'eggs'}), items_add=frozenset({'mineral water'}), confidence=0.28338278931750743, lift=1.188844688294532), OrderedStatistic(items_base=frozenset({'mineral water'}), items_add=frozenset({'eggs'}), confidence=0.21364653243847875, lift=1.188844688294532)]
# --------------------------------------------------------------------------
# Rule:  frozenset({'mineral water', 'ground beef'})  ->  Support:  0.040927876283162246 Confidence:  [OrderedStatistic(items_base=frozenset(), items_add=frozenset({'mineral water', 'ground beef'}), confidence=0.040927876283162246, lift=1.0), OrderedStatistic(items_base=frozenset({'ground beef'}), items_add=frozenset({'mineral water'}), confidence=0.41655359565807326, lift=1.7475215442008991), OrderedStatistic(items_base=frozenset({'mineral water'}), items_add=frozenset({'ground beef'}), confidence=0.17170022371364654, lift=1.7475215442008993)]
# --------------------------------------------------------------------------
# Rule:  frozenset({'mineral water', 'milk'})  ->  Support:  0.04799360085321957 Confidence:  [OrderedStatistic(items_base=frozenset(), items_add=frozenset({'mineral water', 'milk'}), confidence=0.04799360085321957, lift=1.0), OrderedStatistic(items_base=frozenset({'milk'}), items_add=frozenset({'mineral water'}), confidence=0.3703703703703704, lift=1.5537741320739085), OrderedStatistic(items_base=frozenset({'mineral water'}), items_add=frozenset({'milk'}), confidence=0.20134228187919462, lift=1.5537741320739085)]
# --------------------------------------------------------------------------
# Rule:  frozenset({'spaghetti', 'mineral water'})  ->  Support:  0.05972536995067324 Confidence:  [OrderedStatistic(items_base=frozenset(), items_add=frozenset({'spaghetti', 'mineral water'}), confidence=0.05972536995067324, lift=1.0), OrderedStatistic(items_base=frozenset({'mineral water'}), items_add=frozenset({'spaghetti'}), confidence=0.2505592841163311, lift=1.4390851379453289), OrderedStatistic(items_base=frozenset({'spaghetti'}), items_add=frozenset({'mineral water'}), confidence=0.3430321592649311, lift=1.4390851379453289)]
# --------------------------------------------------------------------------
